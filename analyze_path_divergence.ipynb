# %% [markdown]
# # Path Divergence Analysis
#
# This notebook analyzes why FlexDTW and Parflex paths intersect at a point and then diverge by examining the cost matrix and path decisions around that intersection.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import import_ipynb

# Import required modules
import Parflex
import FlexDTW

# Set up plotting style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# %% [markdown]
# ## 1. Data Loading & Setup

# %%
# File paths
file_1 = "/home/ijain/ttmp/Chopin_Mazurkas_features/matching/Chopin_Op017No4/Chopin_Op017No4_Levy-1951_pid915406-13.npy"
file_2 = "/home/ijain/ttmp/Chopin_Mazurkas_features/matching/Chopin_Op017No4/Chopin_Op017No4_Afanassiev-2001_pid9130-01.npy"

# Load feature files
F1 = np.load(file_1)
F2 = np.load(file_2)

print(f"F1 shape: {F1.shape}")
print(f"F2 shape: {F2.shape}")

# Compute cost matrix
C = 1 - FlexDTW.L2norm(F1).T @ FlexDTW.L2norm(F2)
print(f"Cost matrix C shape: {C.shape}")

# Set alignment parameters
steps = np.array([[1, 1], [1, 2], [2, 1]])
weights = np.array([1.25, 3.0, 3.0])
beta = 0.1
L = 4000  # Chunk size for Parflex
# Out:
# F1 shape: (12, 9379)
# F2 shape: (12, 17642)
# Cost matrix C shape: (9379, 17642)

# %% [markdown]
# ## 2. Path Computation

# %%
# Run FlexDTW (same buffer as 04_Align_Benchmarks so path is full-band)
L1, L2 = C.shape[0], C.shape[1]
buffer_flex = min(L1, L2) * (1 - (1 - beta) * min(L1, L2) / max(L1, L2))
print("Running FlexDTW...")
best_cost_flex, wp_flex, D_flex, P_flex, B_flex, debug_flex = FlexDTW.flexdtw(
    C, steps=steps, weights=weights, buffer=buffer_flex
)
print(f"FlexDTW best cost: {best_cost_flex:.6f}")
print(f"FlexDTW path length: {len(wp_flex)}")

# Normalize FlexDTW path to (N, 2) format
if wp_flex.shape[0] == 2:
    wp_flex = wp_flex.T  # Convert (2, N) to (N, 2)
print(f"FlexDTW path shape: {wp_flex.shape}")

# Run Parflex Stage 1
print("\nRunning Parflex Stage 1...")
C_parflex, tiled_result = Parflex.align_system_parflex(
    F1, F2, steps=steps, weights=weights, beta=beta, L=L
)
print(f"Parflex chunks: {tiled_result['n_row']} x {tiled_result['n_col']}")

# Run Parflex Stage 2
print("Running Parflex Stage 2...")
parflex_result = Parflex.parflex_2a(tiled_result, C_parflex, beta=beta, show_fig=False)
wp_parflex = parflex_result['stitched_wp']
print(f"Parflex path length: {len(wp_parflex)}")
print(f"Parflex path shape: {wp_parflex.shape}")

# Ensure Parflex path is (N, 2) format
if wp_parflex.shape[0] == 2:
    wp_parflex = wp_parflex.T
print(f"Parflex normalized path shape: {wp_parflex.shape}")
# Out:
# Running FlexDTW...
# FlexDTW best cost: 0.157340
# FlexDTW path length: 2
# FlexDTW path shape: (9314, 2)
#
# Running Parflex Stage 1...
# Parflex chunks: 3 x 5
# Running Parflex Stage 2...
# [Stage2] transition: chunk(2,1), edge=0, idx=2101 -> chunk(1,1), edge=0, corner_landed=False, S_val=861
# [Stage2] transition: chunk(1,1), edge=0, idx=861 -> chunk(1,0), edge=1, corner_landed=False, S_val=-3216
# [Stage2] transition: chunk(1,0), edge=1, idx=3216 -> chunk(0,0), edge=0, corner_landed=False, S_val=429
# [Stage2] transition: chunk(2,2), edge=0, idx=3900 -> chunk(1,2), edge=0, corner_landed=False, S_val=2520
# [Stage2] transition: chunk(1,2), edge=0, idx=2520 -> chunk(1,1), edge=1, corner_landed=False, S_val=-1366
# [Stage2] transition: chunk(1,1), edge=1, idx=1366 -> chunk(0,1), edge=0, corner_landed=False, S_val=2100
# [Stage2] transition: chunk(0,1), edge=0, idx=2100 -> chunk(0,0), edge=1, corner_landed=False, S_val=-2329
# [Stage2] transition: chunk(2,3), edge=0, idx=3321 -> chunk(1,3), edge=0, corner_landed=False, S_val=1665
# [Stage2] transition: chunk(1,3), edge=0, idx=1665 -> chunk(1,2), edge=1, corner_landed=False, S_val=-2591
# [Stage2] transition: chunk(1,2), edge=1, idx=2591 -> chunk(0,2), edge=0, corner_landed=False, S_val=875
# [Stage2] transition: chunk(0,2), edge=0, idx=875 -> chunk(0,1), edge=1, corner_landed=False, S_val=-3246
# [Stage2] transition: chunk(2,4), edge=0, idx=404 -> chunk(2,3), edge=1, corner_landed=False, S_val=-1047
# [Stage2] transition: chunk(2,3), edge=1, idx=1047 -> chunk(1,3), edge=0, corner_landed=False, S_val=2625
# [Stage2] transition: chunk(1,3), edge=0, idx=2625 -> chunk(1,2), edge=1, corner_landed=False, S_val=-2591
# [Stage2] transition: chunk(1,2), edge=1, idx=2591 -> chunk(0,2), edge=0, corner_landed=False, S_val=875
# [Stage2] transition: chunk(0,2), edge=0, idx=875 -> chunk(0,1), edge=1, corner_landed=False, S_val=-3246
# [Stage2] transition: chunk(1,4), edge=1, idx=892 -> chunk(0,4), edge=0, corner_landed=False, S_val=865
# [Stage2] transition: chunk(0,4), edge=0, idx=865 -> chunk(0,3), edge=1, corner_landed=False, S_val=-3040
# [Stage2] transition: chunk(2,4), edge=0, idx=1645 -> chunk(1,4), edge=0, corner_landed=False, S_val=193
# [Stage2] transition: chunk(1,4), edge=0, idx=193 -> chunk(1,3), edge=1, corner_landed=False, S_val=-3839
# [Stage2] transition: chunk(1,3), edge=1, idx=3839 -> chunk(0,3), edge=0, corner_landed=False, S_val=42
# [Stage2] transition: chunk(0,3), edge=0, idx=42 -> chunk(0,2), edge=1, corner_landed=False, S_val=-3941
# [Stage2] transition: chunk(0,2), edge=1, idx=3941 -> chunk(0,1), edge=1, corner_landed=False, S_val=-545
# [Stage2] transition: chunk(2,3), edge=0, idx=3321 -> chunk(1,3), edge=0, corner_landed=False, S_val=1665
# [Stage2] transition: chunk(1,3), edge=0, idx=1665 -> chunk(1,2), edge=1, corner_landed=False, S_val=-2591
# [Stage2] transition: chunk(1,2), edge=1, idx=2591 -> chunk(0,2), edge=0, corner_landed=False, S_val=875
# [Stage2] transition: chunk(0,2), edge=0, idx=875 -> chunk(0,1), edge=1, corner_landed=False, S_val=-3246
# Parflex path length: 8615
# Parflex path shape: (8615, 2)
# Parflex normalized path shape: (8615, 2)

# %% [markdown]
# ## 3. Intersection Detection

# %%
def find_path_intersections(wp1, wp2, tolerance=2):
    """
    Find intersection points between two warping paths.
    
    Parameters:
    -----------
    wp1, wp2 : ndarray, shape (N, 2)
        Warping paths with columns [row, col]
    tolerance : int
        Manhattan distance tolerance for considering points as intersecting
        
    Returns:
    --------
    intersections : list of dict
        Each dict contains:
        - 'point': (row, col) coordinates
        - 'idx1': index in wp1
        - 'idx2': index in wp2
        - 'distance': Manhattan distance (0 if exact match)
    """
    intersections = []
    
    # Convert paths to sets of tuples for exact matches
    wp1_set = set(tuple(p) for p in wp1)
    wp2_set = set(tuple(p) for p in wp2)
    exact_matches = wp1_set & wp2_set
    
    # Find exact matches first
    for point in exact_matches:
        idx1 = np.where((wp1[:, 0] == point[0]) & (wp1[:, 1] == point[1]))[0]
        idx2 = np.where((wp2[:, 0] == point[0]) & (wp2[:, 1] == point[1]))[0]
        if len(idx1) > 0 and len(idx2) > 0:
            intersections.append({
                'point': point,
                'idx1': idx1[0],
                'idx2': idx2[0],
                'distance': 0
            })
    
    # Find near-misses within tolerance
    for i, p1 in enumerate(wp1):
        for j, p2 in enumerate(wp2):
            manhattan_dist = abs(p1[0] - p2[0]) + abs(p1[1] - p2[1])
            if 0 < manhattan_dist <= tolerance:
                # Check if this is not already an exact match
                point_tuple = tuple(p1)
                if point_tuple not in exact_matches:
                    intersections.append({
                        'point': tuple(p1),
                        'idx1': i,
                        'idx2': j,
                        'distance': manhattan_dist
                    })
                    break  # Only add first near-miss for each wp1 point
    
    return intersections

# Find intersections
intersections = find_path_intersections(wp_flex, wp_parflex, tolerance=2)
print(f"Found {len(intersections)} intersection(s)")
for i, inter in enumerate(intersections):
    print(f"  Intersection {i+1}: {inter['point']} (distance: {inter['distance']}, "
          f"flex_idx: {inter['idx1']}, parflex_idx: {inter['idx2']})")
# Out:
# Found 532 intersection(s)
#   Intersection 1: (np.int64(6787), np.int64(12249)) (distance: 0, flex_idx: 6765, parflex_idx: 6194)
#   Intersection 2: (np.int64(6914), np.int64(12488)) (distance: 0, flex_idx: 6892, parflex_idx: 6321)
#   Intersection 3: (np.int64(6486), np.int64(11800)) (distance: 0, flex_idx: 6464, parflex_idx: 5893)
#   Intersection 4: (np.int64(6682), np.int64(12102)) (distance: 0, flex_idx: 6660, parflex_idx: 6089)
#   Intersection 5: (np.int64(6430), np.int64(11710)) (distance: 0, flex_idx: 6408, parflex_idx: 5837)
#   Intersection 6: (np.int64(6467), np.int64(11768)) (distance: 0, flex_idx: 6445, parflex_idx: 5874)
#   Intersection 7: (np.int64(6838), np.int64(12349)) (distance: 0, flex_idx: 6816, parflex_idx: 6245)
#   Intersection 8: (np.int64(6844), np.int64(12356)) (distance: 0, flex_idx: 6822, parflex_idx: 6251)
#   Intersection 9: (np.int64(6707), np.int64(12140)) (distance: 0, flex_idx: 6685, parflex_idx: 6114)
#   Intersection 10: (np.int64(6728), np.int64(12172)) (distance: 0, flex_idx: 6706, parflex_idx: 6135)
#   Intersection 11: (np.int64(6949), np.int64(12558)) (distance: 0, flex_idx: 6927, parflex_idx: 6356)
#   Intersection 12: (np.int64(6873), np.int64(12410)) (distance: 0, flex_idx: 6851, parflex_idx: 6280)
#   Intersection 13: (np.int64(6688), np.int64(12108)) (distance: 0, flex_idx: 6666, parflex_idx: 6095)
#   Intersection 14: (np.int64(6784), np.int64(12243)) (distance: 0, flex_idx: 6762, parflex_idx: 6191)
#   Intersection 15: (np.int64(6704), np.int64(12134)) (distance: 0, flex_idx: 6682, parflex_idx: 6111)
#   Intersection 16: (np.int64(6805), np.int64(12284)) (distance: 0, flex_idx: 6783, parflex_idx: 6212)
#   Intersection 17: (np.int64(6456), np.int64(11749)) (distance: 0, flex_idx: 6434, parflex_idx: 5863)
#   Intersection 18: (np.int64(6416), np.int64(11685)) (distance: 0, flex_idx: 6394, parflex_idx: 5823)
#   Intersection 19: (np.int64(6689), np.int64(12109)) (distance: 0, flex_idx: 6667, parflex_idx: 6096)
#   Intersection 20: (np.int64(6453), np.int64(11743)) (distance: 0, flex_idx: 6431, parflex_idx: 5860)
#   Intersection 21: (np.int64(6963), np.int64(12586)) (distance: 0, flex_idx: 6941, parflex_idx: 6370)
#   Intersection 22: (np.int64(6887), np.int64(12438)) (distance: 0, flex_idx: 6865, parflex_idx: 6294)
#   Intersection 23: (np.int64(6820), np.int64(12314)) (distance: 0, flex_idx: 6798, parflex_idx: 6227)
#   Intersection 24: (np.int64(6867), np.int64(12398)) (distance: 0, flex_idx: 6845, parflex_idx: 6274)
#   Intersection 25: (np.int64(6736), np.int64(12180)) (distance: 0, flex_idx: 6714, parflex_idx: 6143)
#   Intersection 26: (np.int64(6368), np.int64(11622)) (distance: 0, flex_idx: 6346, parflex_idx: 5775)
#   Intersection 27: (np.int64(6913), np.int64(12486)) (distance: 0, flex_idx: 6891, parflex_idx: 6320)
#   Intersection 28: (np.int64(6485), np.int64(11798)) (distance: 0, flex_idx: 6463, parflex_idx: 5892)
#   Intersection 29: (np.int64(6931), np.int64(12522)) (distance: 0, flex_idx: 6909, parflex_idx: 6338)
#   Intersection 30: (np.int64(6834), np.int64(12342)) (distance: 0, flex_idx: 6812, parflex_idx: 6241)
#   Intersection 31: (np.int64(6855), np.int64(12374)) (distance: 0, flex_idx: 6833, parflex_idx: 6262)
#   Intersection 32: (np.int64(6837), np.int64(12347)) (distance: 0, flex_idx: 6815, parflex_idx: 6244)
#   Intersection 33: (np.int64(6750), np.int64(12199)) (distance: 0, flex_idx: 6728, parflex_idx: 6157)
#   Intersection 34: (np.int64(6427), np.int64(11704)) (distance: 0, flex_idx: 6405, parflex_idx: 5834)
#   Intersection 35: (np.int64(6448), np.int64(11736)) (distance: 0, flex_idx: 6426, parflex_idx: 5855)
#   Intersection 36: (np.int64(6358), np.int64(11604)) (distance: 0, flex_idx: 6336, parflex_idx: 5765)
#   Intersection 37: (np.int64(6848), np.int64(12362)) (distance: 0, flex_idx: 6826, parflex_idx: 6255)
#   Intersection 38: (np.int64(6408), np.int64(11672)) (distance: 0, flex_idx: 6386, parflex_idx: 5815)
#   Intersection 39: (np.int64(6361), np.int64(11609)) (distance: 0, flex_idx: 6339, parflex_idx: 5768)
#   Intersection 40: (np.int64(6411), np.int64(11677)) (distance: 0, flex_idx: 6389, parflex_idx: 5818)
#   Intersection 41: (np.int64(6751), np.int64(12200)) (distance: 0, flex_idx: 6729, parflex_idx: 6158)
#   Intersection 42: (np.int64(6783), np.int64(12241)) (distance: 0, flex_idx: 6761, parflex_idx: 6190)
#   Intersection 43: (np.int64(6473), np.int64(11774)) (distance: 0, flex_idx: 6451, parflex_idx: 5880)
#   Intersection 44: (np.int64(6804), np.int64(12282)) (distance: 0, flex_idx: 6782, parflex_idx: 6211)
#   Intersection 45: (np.int64(6870), np.int64(12404)) (distance: 0, flex_idx: 6848, parflex_idx: 6277)
#   Intersection 46: (np.int64(6375), np.int64(11629)) (distance: 0, flex_idx: 6353, parflex_idx: 5782)
#   Intersection 47: (np.int64(6412), np.int64(11678)) (distance: 0, flex_idx: 6390, parflex_idx: 5819)
#   Intersection 48: (np.int64(6405), np.int64(11666)) (distance: 0, flex_idx: 6383, parflex_idx: 5812)
#   Intersection 49: (np.int64(6739), np.int64(12185)) (distance: 0, flex_idx: 6717, parflex_idx: 6146)
#   Intersection 50: (np.int64(6960), np.int64(12580)) (distance: 0, flex_idx: 6938, parflex_idx: 6367)
#   Intersection 51: (np.int64(6916), np.int64(12492)) (distance: 0, flex_idx: 6894, parflex_idx: 6323)
#   Intersection 52: (np.int64(6758), np.int64(12207)) (distance: 0, flex_idx: 6736, parflex_idx: 6165)
#   Intersection 53: (np.int64(6819), np.int64(12312)) (distance: 0, flex_idx: 6797, parflex_idx: 6226)
#   Intersection 54: (np.int64(6884), np.int64(12432)) (distance: 0, flex_idx: 6862, parflex_idx: 6291)
#   Intersection 55: (np.int64(6743), np.int64(12191)) (distance: 0, flex_idx: 6721, parflex_idx: 6150)
#   Intersection 56: (np.int64(6364), np.int64(11615)) (distance: 0, flex_idx: 6342, parflex_idx: 5771)
#   Intersection 57: (np.int64(6909), np.int64(12479)) (distance: 0, flex_idx: 6887, parflex_idx: 6316)
#   Intersection 58: (np.int64(6786), np.int64(12247)) (distance: 0, flex_idx: 6764, parflex_idx: 6193)
#   Intersection 59: (np.int64(6433), np.int64(11714)) (distance: 0, flex_idx: 6411, parflex_idx: 5840)
#   Intersection 60: (np.int64(6706), np.int64(12138)) (distance: 0, flex_idx: 6684, parflex_idx: 6113)
#   Intersection 61: (np.int64(6930), np.int64(12520)) (distance: 0, flex_idx: 6908, parflex_idx: 6337)
#   Intersection 62: (np.int64(6484), np.int64(11796)) (distance: 0, flex_idx: 6462, parflex_idx: 5891)
#   Intersection 63: (np.int64(6833), np.int64(12340)) (distance: 0, flex_idx: 6811, parflex_idx: 6240)
#   Intersection 64: (np.int64(6854), np.int64(12372)) (distance: 0, flex_idx: 6832, parflex_idx: 6261)
#   Intersection 65: (np.int64(6415), np.int64(11684)) (distance: 0, flex_idx: 6393, parflex_idx: 5822)
#   Intersection 66: (np.int64(6426), np.int64(11702)) (distance: 0, flex_idx: 6404, parflex_idx: 5833)
#   Intersection 67: (np.int64(6434), np.int64(11715)) (distance: 0, flex_idx: 6412, parflex_idx: 5841)
#   Intersection 68: (np.int64(6455), np.int64(11747)) (distance: 0, flex_idx: 6433, parflex_idx: 5862)
#   Intersection 69: (np.int64(6357), np.int64(11602)) (distance: 0, flex_idx: 6335, parflex_idx: 5764)
#   Intersection 70: (np.int64(6847), np.int64(12360)) (distance: 0, flex_idx: 6825, parflex_idx: 6254)
#   Intersection 71: (np.int64(6779), np.int64(12234)) (distance: 0, flex_idx: 6757, parflex_idx: 6186)
#   Intersection 72: (np.int64(6927), np.int64(12514)) (distance: 0, flex_idx: 6905, parflex_idx: 6334)
#   Intersection 73: (np.int64(6945), np.int64(12550)) (distance: 0, flex_idx: 6923, parflex_idx: 6352)
#   Intersection 74: (np.int64(6390), np.int64(11644)) (distance: 0, flex_idx: 6368, parflex_idx: 5797)
#   Intersection 75: (np.int64(6869), np.int64(12402)) (distance: 0, flex_idx: 6847, parflex_idx: 6276)
#   Intersection 76: (np.int64(6676), np.int64(12096)) (distance: 0, flex_idx: 6654, parflex_idx: 6083)
#   Intersection 77: (np.int64(6742), np.int64(12190)) (distance: 0, flex_idx: 6720, parflex_idx: 6149)
#   Intersection 78: (np.int64(6801), np.int64(12276)) (distance: 0, flex_idx: 6779, parflex_idx: 6208)
#   Intersection 79: (np.int64(6452), np.int64(11741)) (distance: 0, flex_idx: 6430, parflex_idx: 5859)
#   Intersection 80: (np.int64(6404), np.int64(11664)) (distance: 0, flex_idx: 6382, parflex_idx: 5811)
#   Intersection 81: (np.int64(6757), np.int64(12206)) (distance: 0, flex_idx: 6735, parflex_idx: 6164)
#   Intersection 82: (np.int64(6677), np.int64(12097)) (distance: 0, flex_idx: 6655, parflex_idx: 6084)
#   Intersection 83: (np.int64(6382), np.int64(11636)) (distance: 0, flex_idx: 6360, parflex_idx: 5789)
#   Intersection 84: (np.int64(6738), np.int64(12183)) (distance: 0, flex_idx: 6716, parflex_idx: 6145)
#   Intersection 85: (np.int64(6959), np.int64(12578)) (distance: 0, flex_idx: 6937, parflex_idx: 6366)
#   Intersection 86: (np.int64(6818), np.int64(12310)) (distance: 0, flex_idx: 6796, parflex_idx: 6225)
#   Intersection 87: (np.int64(6883), np.int64(12430)) (distance: 0, flex_idx: 6861, parflex_idx: 6290)
#   Intersection 88: (np.int64(6836), np.int64(12346)) (distance: 0, flex_idx: 6814, parflex_idx: 6243)
#   Intersection 89: (np.int64(6683), np.int64(12103)) (distance: 0, flex_idx: 6661, parflex_idx: 6090)
#   Intersection 90: (np.int64(6840), np.int64(12352)) (distance: 0, flex_idx: 6818, parflex_idx: 6247)
#   Intersection 91: (np.int64(6724), np.int64(12168)) (distance: 0, flex_idx: 6702, parflex_idx: 6131)
#   Intersection 92: (np.int64(6908), np.int64(12477)) (distance: 0, flex_idx: 6886, parflex_idx: 6315)
#   Intersection 93: (np.int64(6764), np.int64(12213)) (distance: 0, flex_idx: 6742, parflex_idx: 6171)
#   Intersection 94: (np.int64(6684), np.int64(12104)) (distance: 0, flex_idx: 6662, parflex_idx: 6091)
#   Intersection 95: (np.int64(6772), np.int64(12226)) (distance: 0, flex_idx: 6750, parflex_idx: 6179)
#   Intersection 96: (np.int64(6785), np.int64(12245)) (distance: 0, flex_idx: 6763, parflex_idx: 6192)
#   Intersection 97: (np.int64(6705), np.int64(12136)) (distance: 0, flex_idx: 6683, parflex_idx: 6112)
#   Intersection 98: (np.int64(6414), np.int64(11682)) (distance: 0, flex_idx: 6392, parflex_idx: 5821)
#   Intersection 99: (np.int64(6778), np.int64(12233)) (distance: 0, flex_idx: 6756, parflex_idx: 6185)
#   Intersection 100: (np.int64(6425), np.int64(11700)) (distance: 0, flex_idx: 6403, parflex_idx: 5832)
#   Intersection 101: (np.int64(6454), np.int64(11745)) (distance: 0, flex_idx: 6432, parflex_idx: 5861)
#   Intersection 102: (np.int64(6702), np.int64(12130)) (distance: 0, flex_idx: 6680, parflex_idx: 6109)
#   Intersection 103: (np.int64(6944), np.int64(12548)) (distance: 0, flex_idx: 6922, parflex_idx: 6351)
#   Intersection 104: (np.int64(6962), np.int64(12584)) (distance: 0, flex_idx: 6940, parflex_idx: 6369)
#   Intersection 105: (np.int64(6731), np.int64(12175)) (distance: 0, flex_idx: 6709, parflex_idx: 6138)
#   Intersection 106: (np.int64(6868), np.int64(12400)) (distance: 0, flex_idx: 6846, parflex_idx: 6275)
#   Intersection 107: (np.int64(6691), np.int64(12111)) (distance: 0, flex_idx: 6669, parflex_idx: 6098)
#   Intersection 108: (np.int64(6800), np.int64(12274)) (distance: 0, flex_idx: 6778, parflex_idx: 6207)
#   Intersection 109: (np.int64(6451), np.int64(11739)) (distance: 0, flex_idx: 6429, parflex_idx: 5858)
#   Intersection 110: (np.int64(6723), np.int64(12167)) (distance: 0, flex_idx: 6701, parflex_idx: 6130)
#   Intersection 111: (np.int64(6363), np.int64(11613)) (distance: 0, flex_idx: 6341, parflex_idx: 5770)
#   Intersection 112: (np.int64(6745), np.int64(12194)) (distance: 0, flex_idx: 6723, parflex_idx: 6152)
#   Intersection 113: (np.int64(6958), np.int64(12576)) (distance: 0, flex_idx: 6936, parflex_idx: 6365)
#   Intersection 114: (np.int64(6835), np.int64(12344)) (distance: 0, flex_idx: 6813, parflex_idx: 6242)
#   Intersection 115: (np.int64(6912), np.int64(12484)) (distance: 0, flex_idx: 6890, parflex_idx: 6319)
#   Intersection 116: (np.int64(6483), np.int64(11794)) (distance: 0, flex_idx: 6461, parflex_idx: 5890)
#   Intersection 117: (np.int64(6815), np.int64(12304)) (distance: 0, flex_idx: 6793, parflex_idx: 6222)
#   Intersection 118: (np.int64(6359), np.int64(11606)) (distance: 0, flex_idx: 6337, parflex_idx: 5766)
#   Intersection 119: (np.int64(6468), np.int64(11769)) (distance: 0, flex_idx: 6446, parflex_idx: 5875)
#   Intersection 120: (np.int64(6771), np.int64(12224)) (distance: 0, flex_idx: 6749, parflex_idx: 6178)
#   Intersection 121: (np.int64(6360), np.int64(11607)) (distance: 0, flex_idx: 6338, parflex_idx: 5767)
#   Intersection 122: (np.int64(6389), np.int64(11643)) (distance: 0, flex_idx: 6367, parflex_idx: 5796)
#   Intersection 123: (np.int64(6973), np.int64(12606)) (distance: 0, flex_idx: 6951, parflex_idx: 6380)
#   Intersection 124: (np.int64(6897), np.int64(12458)) (distance: 0, flex_idx: 6875, parflex_idx: 6304)
#   Intersection 125: (np.int64(6469), np.int64(11770)) (distance: 0, flex_idx: 6447, parflex_idx: 5876)
#   Intersection 126: (np.int64(6905), np.int64(12471)) (distance: 0, flex_idx: 6883, parflex_idx: 6312)
#   Intersection 127: (np.int64(6782), np.int64(12239)) (distance: 0, flex_idx: 6760, parflex_idx: 6189)
#   Intersection 128: (np.int64(6926), np.int64(12512)) (distance: 0, flex_idx: 6904, parflex_idx: 6333)
#   Intersection 129: (np.int64(6450), np.int64(11738)) (distance: 0, flex_idx: 6428, parflex_idx: 5857)
#   Intersection 130: (np.int64(6829), np.int64(12332)) (distance: 0, flex_idx: 6807, parflex_idx: 6236)
#   Intersection 131: (np.int64(6803), np.int64(12280)) (distance: 0, flex_idx: 6781, parflex_idx: 6210)
#   Intersection 132: (np.int64(6406), np.int64(11668)) (distance: 0, flex_idx: 6384, parflex_idx: 5813)
#   Intersection 133: (np.int64(6422), np.int64(11694)) (distance: 0, flex_idx: 6400, parflex_idx: 5829)
#   Intersection 134: (np.int64(6961), np.int64(12582)) (distance: 0, flex_idx: 6939, parflex_idx: 6368)
#   Intersection 135: (np.int64(6418), np.int64(11687)) (distance: 0, flex_idx: 6396, parflex_idx: 5825)
#   Intersection 136: (np.int64(6716), np.int64(12158)) (distance: 0, flex_idx: 6694, parflex_idx: 6123)
#   Intersection 137: (np.int64(6941), np.int64(12542)) (distance: 0, flex_idx: 6919, parflex_idx: 6348)
#   Intersection 138: (np.int64(6817), np.int64(12308)) (distance: 0, flex_idx: 6795, parflex_idx: 6224)
#   Intersection 139: (np.int64(6865), np.int64(12394)) (distance: 0, flex_idx: 6843, parflex_idx: 6272)
#   Intersection 140: (np.int64(6362), np.int64(11611)) (distance: 0, flex_idx: 6340, parflex_idx: 5769)
#   Intersection 141: (np.int64(6370), np.int64(11624)) (distance: 0, flex_idx: 6348, parflex_idx: 5777)
#   Intersection 142: (np.int64(6975), np.int64(12610)) (distance: 0, flex_idx: 6953, parflex_idx: 6382)
#   Intersection 143: (np.int64(6882), np.int64(12428)) (distance: 0, flex_idx: 6860, parflex_idx: 6289)
#   Intersection 144: (np.int64(6955), np.int64(12570)) (distance: 0, flex_idx: 6933, parflex_idx: 6362)
#   Intersection 145: (np.int64(6911), np.int64(12482)) (distance: 0, flex_idx: 6889, parflex_idx: 6318)
#   Intersection 146: (np.int64(6482), np.int64(11792)) (distance: 0, flex_idx: 6460, parflex_idx: 5889)
#   Intersection 147: (np.int64(6832), np.int64(12338)) (distance: 0, flex_idx: 6810, parflex_idx: 6239)
#   Intersection 148: (np.int64(6814), np.int64(12302)) (distance: 0, flex_idx: 6792, parflex_idx: 6221)
#   Intersection 149: (np.int64(6879), np.int64(12422)) (distance: 0, flex_idx: 6857, parflex_idx: 6286)
#   Intersection 150: (np.int64(6424), np.int64(11698)) (distance: 0, flex_idx: 6402, parflex_idx: 5831)
#   Intersection 151: (np.int64(6972), np.int64(12604)) (distance: 0, flex_idx: 6950, parflex_idx: 6379)
#   Intersection 152: (np.int64(6690), np.int64(12110)) (distance: 0, flex_idx: 6668, parflex_idx: 6097)
#   Intersection 153: (np.int64(6417), np.int64(11686)) (distance: 0, flex_idx: 6395, parflex_idx: 5824)
#   Intersection 154: (np.int64(6904), np.int64(12469)) (distance: 0, flex_idx: 6882, parflex_idx: 6311)
#   Intersection 155: (np.int64(6752), np.int64(12201)) (distance: 0, flex_idx: 6730, parflex_idx: 6159)
#   Intersection 156: (np.int64(6701), np.int64(12128)) (distance: 0, flex_idx: 6679, parflex_idx: 6108)
#   Intersection 157: (np.int64(6781), np.int64(12237)) (distance: 0, flex_idx: 6759, parflex_idx: 6188)
#   Intersection 158: (np.int64(6436), np.int64(11717)) (distance: 0, flex_idx: 6414, parflex_idx: 5843)
#   Intersection 159: (np.int64(6925), np.int64(12510)) (distance: 0, flex_idx: 6903, parflex_idx: 6332)
#   Intersection 160: (np.int64(6943), np.int64(12546)) (distance: 0, flex_idx: 6921, parflex_idx: 6350)
#   Intersection 161: (np.int64(6802), np.int64(12278)) (distance: 0, flex_idx: 6780, parflex_idx: 6209)
#   Intersection 162: (np.int64(6421), np.int64(11692)) (distance: 0, flex_idx: 6399, parflex_idx: 5828)
#   Intersection 163: (np.int64(6940), np.int64(12540)) (distance: 0, flex_idx: 6918, parflex_idx: 6347)
#   Intersection 164: (np.int64(6816), np.int64(12306)) (distance: 0, flex_idx: 6794, parflex_idx: 6223)
#   Intersection 165: (np.int64(6719), np.int64(12163)) (distance: 0, flex_idx: 6697, parflex_idx: 6126)
#   Intersection 166: (np.int64(6799), np.int64(12272)) (distance: 0, flex_idx: 6777, parflex_idx: 6206)
#   Intersection 167: (np.int64(6864), np.int64(12392)) (distance: 0, flex_idx: 6842, parflex_idx: 6271)
#   Intersection 168: (np.int64(6759), np.int64(12208)) (distance: 0, flex_idx: 6737, parflex_idx: 6166)
#   Intersection 169: (np.int64(6679), np.int64(12099)) (distance: 0, flex_idx: 6657, parflex_idx: 6086)
#   Intersection 170: (np.int64(6369), np.int64(11623)) (distance: 0, flex_idx: 6347, parflex_idx: 5776)
#   Intersection 171: (np.int64(6796), np.int64(12266)) (distance: 0, flex_idx: 6774, parflex_idx: 6203)
#   Intersection 172: (np.int64(6773), np.int64(12228)) (distance: 0, flex_idx: 6751, parflex_idx: 6180)
#   Intersection 173: (np.int64(6907), np.int64(12475)) (distance: 0, flex_idx: 6885, parflex_idx: 6314)
#   Intersection 174: (np.int64(6954), np.int64(12568)) (distance: 0, flex_idx: 6932, parflex_idx: 6361)
#   Intersection 175: (np.int64(6928), np.int64(12516)) (distance: 0, flex_idx: 6906, parflex_idx: 6335)
#   Intersection 176: (np.int64(6831), np.int64(12336)) (distance: 0, flex_idx: 6809, parflex_idx: 6238)
#   Intersection 177: (np.int64(6774), np.int64(12229)) (distance: 0, flex_idx: 6752, parflex_idx: 6181)
#   Intersection 178: (np.int64(6896), np.int64(12456)) (distance: 0, flex_idx: 6874, parflex_idx: 6303)
#   Intersection 179: (np.int64(6842), np.int64(12354)) (distance: 0, flex_idx: 6820, parflex_idx: 6249)
#   Intersection 180: (np.int64(6479), np.int64(11786)) (distance: 0, flex_idx: 6457, parflex_idx: 5886)
#   Intersection 181: (np.int64(6726), np.int64(12170)) (distance: 0, flex_idx: 6704, parflex_idx: 6133)
#   Intersection 182: (np.int64(6766), np.int64(12215)) (distance: 0, flex_idx: 6744, parflex_idx: 6173)
#   Intersection 183: (np.int64(6376), np.int64(11630)) (distance: 0, flex_idx: 6354, parflex_idx: 5783)
#   Intersection 184: (np.int64(6435), np.int64(11716)) (distance: 0, flex_idx: 6413, parflex_idx: 5842)
#   Intersection 185: (np.int64(6443), np.int64(11729)) (distance: 0, flex_idx: 6421, parflex_idx: 5850)
#   Intersection 186: (np.int64(6700), np.int64(12126)) (distance: 0, flex_idx: 6678, parflex_idx: 6107)
#   Intersection 187: (np.int64(6718), np.int64(12162)) (distance: 0, flex_idx: 6696, parflex_idx: 6125)
#   Intersection 188: (np.int64(6377), np.int64(11631)) (distance: 0, flex_idx: 6355, parflex_idx: 5784)
#   Intersection 189: (np.int64(6942), np.int64(12544)) (distance: 0, flex_idx: 6920, parflex_idx: 6349)
#   Intersection 190: (np.int64(6893), np.int64(12450)) (distance: 0, flex_idx: 6871, parflex_idx: 6300)
#   Intersection 191: (np.int64(6922), np.int64(12504)) (distance: 0, flex_idx: 6900, parflex_idx: 6329)
#   Intersection 192: (np.int64(6420), np.int64(11690)) (distance: 0, flex_idx: 6398, parflex_idx: 5827)
#   Intersection 193: (np.int64(6733), np.int64(12177)) (distance: 0, flex_idx: 6711, parflex_idx: 6140)
#   Intersection 194: (np.int64(6383), np.int64(11637)) (distance: 0, flex_idx: 6361, parflex_idx: 5790)
#   Intersection 195: (np.int64(6744), np.int64(12192)) (distance: 0, flex_idx: 6722, parflex_idx: 6151)
#   Intersection 196: (np.int64(6715), np.int64(12156)) (distance: 0, flex_idx: 6693, parflex_idx: 6122)
#   Intersection 197: (np.int64(6939), np.int64(12538)) (distance: 0, flex_idx: 6917, parflex_idx: 6346)
#   Intersection 198: (np.int64(6957), np.int64(12574)) (distance: 0, flex_idx: 6935, parflex_idx: 6364)
#   Intersection 199: (np.int64(6863), np.int64(12390)) (distance: 0, flex_idx: 6841, parflex_idx: 6270)
#   Intersection 200: (np.int64(6881), np.int64(12426)) (distance: 0, flex_idx: 6859, parflex_idx: 6288)
#   Intersection 201: (np.int64(6725), np.int64(12169)) (distance: 0, flex_idx: 6703, parflex_idx: 6132)
#   Intersection 202: (np.int64(6384), np.int64(11638)) (distance: 0, flex_idx: 6362, parflex_idx: 5791)
#   Intersection 203: (np.int64(6910), np.int64(12480)) (distance: 0, flex_idx: 6888, parflex_idx: 6317)
#   Intersection 204: (np.int64(6813), np.int64(12300)) (distance: 0, flex_idx: 6791, parflex_idx: 6220)
#   Intersection 205: (np.int64(6464), np.int64(11765)) (distance: 0, flex_idx: 6442, parflex_idx: 5871)
#   Intersection 206: (np.int64(6445), np.int64(11733)) (distance: 0, flex_idx: 6423, parflex_idx: 5852)
#   Intersection 207: (np.int64(6906), np.int64(12473)) (distance: 0, flex_idx: 6884, parflex_idx: 6313)
#   Intersection 208: (np.int64(6770), np.int64(12222)) (distance: 0, flex_idx: 6748, parflex_idx: 6177)
#   Intersection 209: (np.int64(6703), np.int64(12132)) (distance: 0, flex_idx: 6681, parflex_idx: 6110)
#   Intersection 210: (np.int64(6971), np.int64(12602)) (distance: 0, flex_idx: 6949, parflex_idx: 6378)
#   Intersection 211: (np.int64(6446), np.int64(11734)) (distance: 0, flex_idx: 6424, parflex_idx: 5853)
#   Intersection 212: (np.int64(6830), np.int64(12334)) (distance: 0, flex_idx: 6808, parflex_idx: 6237)
#   Intersection 213: (np.int64(6878), np.int64(12420)) (distance: 0, flex_idx: 6856, parflex_idx: 6285)
#   Intersection 214: (np.int64(6780), np.int64(12235)) (distance: 0, flex_idx: 6758, parflex_idx: 6187)
#   Intersection 215: (np.int64(6470), np.int64(11771)) (distance: 0, flex_idx: 6448, parflex_idx: 5877)
#   Intersection 216: (np.int64(6478), np.int64(11784)) (distance: 0, flex_idx: 6456, parflex_idx: 5885)
#   Intersection 217: (np.int64(6423), np.int64(11696)) (distance: 0, flex_idx: 6401, parflex_idx: 5830)
#   Intersection 218: (np.int64(6391), np.int64(11645)) (distance: 0, flex_idx: 6369, parflex_idx: 5798)
#   Intersection 219: (np.int64(6442), np.int64(11727)) (distance: 0, flex_idx: 6420, parflex_idx: 5849)
#   Intersection 220: (np.int64(6471), np.int64(11772)) (distance: 0, flex_idx: 6449, parflex_idx: 5878)
#   Intersection 221: (np.int64(6717), np.int64(12160)) (distance: 0, flex_idx: 6695, parflex_idx: 6124)
#   Intersection 222: (np.int64(6892), np.int64(12448)) (distance: 0, flex_idx: 6870, parflex_idx: 6299)
#   Intersection 223: (np.int64(6678), np.int64(12098)) (distance: 0, flex_idx: 6656, parflex_idx: 6085)
#   Intersection 224: (np.int64(6866), np.int64(12396)) (distance: 0, flex_idx: 6844, parflex_idx: 6273)
#   Intersection 225: (np.int64(6697), np.int64(12120)) (distance: 0, flex_idx: 6675, parflex_idx: 6104)
#   Intersection 226: (np.int64(6921), np.int64(12502)) (distance: 0, flex_idx: 6899, parflex_idx: 6328)
#   Intersection 227: (np.int64(6798), np.int64(12270)) (distance: 0, flex_idx: 6776, parflex_idx: 6205)
#   Intersection 228: (np.int64(6714), np.int64(12154)) (distance: 0, flex_idx: 6692, parflex_idx: 6121)
#   Intersection 229: (np.int64(6974), np.int64(12608)) (distance: 0, flex_idx: 6952, parflex_idx: 6381)
#   Intersection 230: (np.int64(6956), np.int64(12572)) (distance: 0, flex_idx: 6934, parflex_idx: 6363)
#   Intersection 231: (np.int64(6880), np.int64(12424)) (distance: 0, flex_idx: 6858, parflex_idx: 6287)
#   Intersection 232: (np.int64(6841), np.int64(12353)) (distance: 0, flex_idx: 6819, parflex_idx: 6248)
#   Intersection 233: (np.int64(6791), np.int64(12257)) (distance: 0, flex_idx: 6769, parflex_idx: 6198)
#   Intersection 234: (np.int64(6481), np.int64(11790)) (distance: 0, flex_idx: 6459, parflex_idx: 5888)
#   Intersection 235: (np.int64(6685), np.int64(12105)) (distance: 0, flex_idx: 6663, parflex_idx: 6092)
#   Intersection 236: (np.int64(6860), np.int64(12384)) (distance: 0, flex_idx: 6838, parflex_idx: 6267)
#   Intersection 237: (np.int64(6812), np.int64(12298)) (distance: 0, flex_idx: 6790, parflex_idx: 6219)
#   Intersection 238: (np.int64(6765), np.int64(12214)) (distance: 0, flex_idx: 6743, parflex_idx: 6172)
#   Intersection 239: (np.int64(6463), np.int64(11763)) (distance: 0, flex_idx: 6441, parflex_idx: 5870)
#   Intersection 240: (np.int64(6747), np.int64(12196)) (distance: 0, flex_idx: 6725, parflex_idx: 6154)
#   Intersection 241: (np.int64(6769), np.int64(12220)) (distance: 0, flex_idx: 6747, parflex_idx: 6176)
#   Intersection 242: (np.int64(6895), np.int64(12454)) (distance: 0, flex_idx: 6873, parflex_idx: 6302)
#   Intersection 243: (np.int64(6903), np.int64(12467)) (distance: 0, flex_idx: 6881, parflex_idx: 6310)
#   Intersection 244: (np.int64(6924), np.int64(12508)) (distance: 0, flex_idx: 6902, parflex_idx: 6331)
#   Intersection 245: (np.int64(6827), np.int64(12328)) (distance: 0, flex_idx: 6805, parflex_idx: 6234)
#   Intersection 246: (np.int64(6732), np.int64(12176)) (distance: 0, flex_idx: 6710, parflex_idx: 6139)
#   Intersection 247: (np.int64(6692), np.int64(12112)) (distance: 0, flex_idx: 6670, parflex_idx: 6099)
#   Intersection 248: (np.int64(6899), np.int64(12460)) (distance: 0, flex_idx: 6877, parflex_idx: 6306)
#   Intersection 249: (np.int64(6754), np.int64(12203)) (distance: 0, flex_idx: 6732, parflex_idx: 6161)
#   Intersection 250: (np.int64(6696), np.int64(12118)) (distance: 0, flex_idx: 6674, parflex_idx: 6103)
#   Intersection 251: (np.int64(6938), np.int64(12536)) (distance: 0, flex_idx: 6916, parflex_idx: 6345)
#   Intersection 252: (np.int64(6797), np.int64(12268)) (distance: 0, flex_idx: 6775, parflex_idx: 6204)
#   Intersection 253: (np.int64(6862), np.int64(12388)) (distance: 0, flex_idx: 6840, parflex_idx: 6269)
#   Intersection 254: (np.int64(6746), np.int64(12195)) (distance: 0, flex_idx: 6724, parflex_idx: 6153)
#   Intersection 255: (np.int64(6721), np.int64(12165)) (distance: 0, flex_idx: 6699, parflex_idx: 6128)
#   Intersection 256: (np.int64(6371), np.int64(11625)) (distance: 0, flex_idx: 6349, parflex_idx: 5778)
#   Intersection 257: (np.int64(6480), np.int64(11788)) (distance: 0, flex_idx: 6458, parflex_idx: 5887)
#   Intersection 258: (np.int64(6859), np.int64(12382)) (distance: 0, flex_idx: 6837, parflex_idx: 6266)
#   Intersection 259: (np.int64(6877), np.int64(12418)) (distance: 0, flex_idx: 6855, parflex_idx: 6284)
#   Intersection 260: (np.int64(6898), np.int64(12459)) (distance: 0, flex_idx: 6876, parflex_idx: 6305)
#   Intersection 261: (np.int64(6372), np.int64(11626)) (distance: 0, flex_idx: 6350, parflex_idx: 5779)
#   Intersection 262: (np.int64(6444), np.int64(11731)) (distance: 0, flex_idx: 6422, parflex_idx: 5851)
#   Intersection 263: (np.int64(6852), np.int64(12370)) (distance: 0, flex_idx: 6830, parflex_idx: 6259)
#   Intersection 264: (np.int64(6441), np.int64(11725)) (distance: 0, flex_idx: 6419, parflex_idx: 5848)
#   Intersection 265: (np.int64(6776), np.int64(12231)) (distance: 0, flex_idx: 6754, parflex_idx: 6183)
#   Intersection 266: (np.int64(6970), np.int64(12600)) (distance: 0, flex_idx: 6948, parflex_idx: 6377)
#   Intersection 267: (np.int64(6894), np.int64(12452)) (distance: 0, flex_idx: 6872, parflex_idx: 6301)
#   Intersection 268: (np.int64(6902), np.int64(12465)) (distance: 0, flex_idx: 6880, parflex_idx: 6309)
#   Intersection 269: (np.int64(6699), np.int64(12124)) (distance: 0, flex_idx: 6677, parflex_idx: 6106)
#   Intersection 270: (np.int64(6967), np.int64(12594)) (distance: 0, flex_idx: 6945, parflex_idx: 6374)
#   Intersection 271: (np.int64(6923), np.int64(12506)) (distance: 0, flex_idx: 6901, parflex_idx: 6330)
#   Intersection 272: (np.int64(6477), np.int64(11782)) (distance: 0, flex_idx: 6455, parflex_idx: 5884)
#   Intersection 273: (np.int64(6826), np.int64(12326)) (distance: 0, flex_idx: 6804, parflex_idx: 6233)
#   Intersection 274: (np.int64(6378), np.int64(11632)) (distance: 0, flex_idx: 6356, parflex_idx: 5785)
#   Intersection 275: (np.int64(6437), np.int64(11718)) (distance: 0, flex_idx: 6415, parflex_idx: 5844)
#   Intersection 276: (np.int64(6474), np.int64(11776)) (distance: 0, flex_idx: 6452, parflex_idx: 5881)
#   Intersection 277: (np.int64(6419), np.int64(11688)) (distance: 0, flex_idx: 6397, parflex_idx: 5826)
#   Intersection 278: (np.int64(6720), np.int64(12164)) (distance: 0, flex_idx: 6698, parflex_idx: 6127)
#   Intersection 279: (np.int64(6379), np.int64(11633)) (distance: 0, flex_idx: 6357, parflex_idx: 5786)
#   Intersection 280: (np.int64(6695), np.int64(12116)) (distance: 0, flex_idx: 6673, parflex_idx: 6102)
#   Intersection 281: (np.int64(6713), np.int64(12152)) (distance: 0, flex_idx: 6691, parflex_idx: 6120)
#   Intersection 282: (np.int64(6920), np.int64(12500)) (distance: 0, flex_idx: 6898, parflex_idx: 6327)
#   Intersection 283: (np.int64(6794), np.int64(12262)) (distance: 0, flex_idx: 6772, parflex_idx: 6201)
#   Intersection 284: (np.int64(6462), np.int64(11761)) (distance: 0, flex_idx: 6440, parflex_idx: 5869)
#   Intersection 285: (np.int64(6775), np.int64(12230)) (distance: 0, flex_idx: 6753, parflex_idx: 6182)
#   Intersection 286: (np.int64(6386), np.int64(11640)) (distance: 0, flex_idx: 6364, parflex_idx: 5793)
#   Intersection 287: (np.int64(6790), np.int64(12255)) (distance: 0, flex_idx: 6768, parflex_idx: 6197)
#   Intersection 288: (np.int64(6768), np.int64(12218)) (distance: 0, flex_idx: 6746, parflex_idx: 6175)
#   Intersection 289: (np.int64(6934), np.int64(12528)) (distance: 0, flex_idx: 6912, parflex_idx: 6341)
#   Intersection 290: (np.int64(6952), np.int64(12564)) (distance: 0, flex_idx: 6930, parflex_idx: 6359)
#   Intersection 291: (np.int64(6466), np.int64(11767)) (distance: 0, flex_idx: 6444, parflex_idx: 5873)
#   Intersection 292: (np.int64(6811), np.int64(12296)) (distance: 0, flex_idx: 6789, parflex_idx: 6218)
#   Intersection 293: (np.int64(6876), np.int64(12416)) (distance: 0, flex_idx: 6854, parflex_idx: 6283)
#   Intersection 294: (np.int64(6400), np.int64(11660)) (distance: 0, flex_idx: 6378, parflex_idx: 5807)
#   Intersection 295: (np.int64(6808), np.int64(12290)) (distance: 0, flex_idx: 6786, parflex_idx: 6215)
#   Intersection 296: (np.int64(6753), np.int64(12202)) (distance: 0, flex_idx: 6731, parflex_idx: 6160)
#   Intersection 297: (np.int64(6459), np.int64(11755)) (distance: 0, flex_idx: 6437, parflex_idx: 5866)
#   Intersection 298: (np.int64(6401), np.int64(11661)) (distance: 0, flex_idx: 6379, parflex_idx: 5808)
#   Intersection 299: (np.int64(6901), np.int64(12463)) (distance: 0, flex_idx: 6879, parflex_idx: 6308)
#   Intersection 300: (np.int64(6698), np.int64(12122)) (distance: 0, flex_idx: 6676, parflex_idx: 6105)
#   Intersection 301: (np.int64(6891), np.int64(12446)) (distance: 0, flex_idx: 6869, parflex_idx: 6298)
#   Intersection 302: (np.int64(6397), np.int64(11654)) (distance: 0, flex_idx: 6375, parflex_idx: 5804)
#   Intersection 303: (np.int64(6760), np.int64(12209)) (distance: 0, flex_idx: 6738, parflex_idx: 6167)
#   Intersection 304: (np.int64(6680), np.int64(12100)) (distance: 0, flex_idx: 6658, parflex_idx: 6087)
#   Intersection 305: (np.int64(6712), np.int64(12150)) (distance: 0, flex_idx: 6690, parflex_idx: 6119)
#   Intersection 306: (np.int64(6937), np.int64(12534)) (distance: 0, flex_idx: 6915, parflex_idx: 6344)
#   Intersection 307: (np.int64(6761), np.int64(12210)) (distance: 0, flex_idx: 6739, parflex_idx: 6168)
#   Intersection 308: (np.int64(6861), np.int64(12386)) (distance: 0, flex_idx: 6839, parflex_idx: 6268)
#   Intersection 309: (np.int64(6793), np.int64(12260)) (distance: 0, flex_idx: 6771, parflex_idx: 6200)
#   Intersection 310: (np.int64(6858), np.int64(12380)) (distance: 0, flex_idx: 6836, parflex_idx: 6265)
#   Intersection 311: (np.int64(6385), np.int64(11639)) (distance: 0, flex_idx: 6363, parflex_idx: 5792)
#   Intersection 312: (np.int64(6461), np.int64(11759)) (distance: 0, flex_idx: 6439, parflex_idx: 5868)
#   Intersection 313: (np.int64(6465), np.int64(11766)) (distance: 0, flex_idx: 6443, parflex_idx: 5872)
#   Intersection 314: (np.int64(6843), np.int64(12355)) (distance: 0, flex_idx: 6821, parflex_idx: 6250)
#   Intersection 315: (np.int64(6851), np.int64(12368)) (distance: 0, flex_idx: 6829, parflex_idx: 6258)
#   Intersection 316: (np.int64(6727), np.int64(12171)) (distance: 0, flex_idx: 6705, parflex_idx: 6134)
#   Intersection 317: (np.int64(6709), np.int64(12144)) (distance: 0, flex_idx: 6687, parflex_idx: 6116)
#   Intersection 318: (np.int64(6767), np.int64(12216)) (distance: 0, flex_idx: 6745, parflex_idx: 6174)
#   Intersection 319: (np.int64(6687), np.int64(12107)) (distance: 0, flex_idx: 6665, parflex_idx: 6094)
#   Intersection 320: (np.int64(6951), np.int64(12562)) (distance: 0, flex_idx: 6929, parflex_idx: 6358)
#   Intersection 321: (np.int64(6969), np.int64(12598)) (distance: 0, flex_idx: 6947, parflex_idx: 6376)
#   Intersection 322: (np.int64(6828), np.int64(12330)) (distance: 0, flex_idx: 6806, parflex_idx: 6235)
#   Intersection 323: (np.int64(6875), np.int64(12414)) (distance: 0, flex_idx: 6853, parflex_idx: 6282)
#   Intersection 324: (np.int64(6447), np.int64(11735)) (distance: 0, flex_idx: 6425, parflex_idx: 5854)
#   Intersection 325: (np.int64(6399), np.int64(11658)) (distance: 0, flex_idx: 6377, parflex_idx: 5806)
#   Intersection 326: (np.int64(6476), np.int64(11780)) (distance: 0, flex_idx: 6454, parflex_idx: 5883)
#   Intersection 327: (np.int64(6825), np.int64(12324)) (distance: 0, flex_idx: 6803, parflex_idx: 6232)
#   Intersection 328: (np.int64(6458), np.int64(11753)) (distance: 0, flex_idx: 6436, parflex_idx: 5865)
#   Intersection 329: (np.int64(6440), np.int64(11723)) (distance: 0, flex_idx: 6418, parflex_idx: 5847)
#   Intersection 330: (np.int64(6392), np.int64(11646)) (distance: 0, flex_idx: 6370, parflex_idx: 5799)
#   Intersection 331: (np.int64(6966), np.int64(12592)) (distance: 0, flex_idx: 6944, parflex_idx: 6373)
#   Intersection 332: (np.int64(6890), np.int64(12444)) (distance: 0, flex_idx: 6868, parflex_idx: 6297)
#   Intersection 333: (np.int64(6734), np.int64(12178)) (distance: 0, flex_idx: 6712, parflex_idx: 6141)
#   Intersection 334: (np.int64(6393), np.int64(11647)) (distance: 0, flex_idx: 6371, parflex_idx: 5800)
#   Intersection 335: (np.int64(6919), np.int64(12498)) (distance: 0, flex_idx: 6897, parflex_idx: 6326)
#   Intersection 336: (np.int64(6822), np.int64(12318)) (distance: 0, flex_idx: 6800, parflex_idx: 6229)
#   Intersection 337: (np.int64(6735), np.int64(12179)) (distance: 0, flex_idx: 6713, parflex_idx: 6142)
#   Intersection 338: (np.int64(6367), np.int64(11621)) (distance: 0, flex_idx: 6345, parflex_idx: 5774)
#   Intersection 339: (np.int64(6789), np.int64(12253)) (distance: 0, flex_idx: 6767, parflex_idx: 6196)
#   Intersection 340: (np.int64(6933), np.int64(12526)) (distance: 0, flex_idx: 6911, parflex_idx: 6340)
#   Intersection 341: (np.int64(6792), np.int64(12258)) (distance: 0, flex_idx: 6770, parflex_idx: 6199)
#   Intersection 342: (np.int64(6810), np.int64(12294)) (distance: 0, flex_idx: 6788, parflex_idx: 6217)
#   Intersection 343: (np.int64(6686), np.int64(12106)) (distance: 0, flex_idx: 6664, parflex_idx: 6093)
#   Intersection 344: (np.int64(6429), np.int64(11708)) (distance: 0, flex_idx: 6407, parflex_idx: 5836)
#   Intersection 345: (np.int64(6432), np.int64(11713)) (distance: 0, flex_idx: 6410, parflex_idx: 5839)
#   Intersection 346: (np.int64(6850), np.int64(12366)) (distance: 0, flex_idx: 6828, parflex_idx: 6257)
#   Intersection 347: (np.int64(6968), np.int64(12596)) (distance: 0, flex_idx: 6946, parflex_idx: 6375)
#   Intersection 348: (np.int64(6900), np.int64(12461)) (distance: 0, flex_idx: 6878, parflex_idx: 6307)
#   Intersection 349: (np.int64(6472), np.int64(11773)) (distance: 0, flex_idx: 6450, parflex_idx: 5879)
#   Intersection 350: (np.int64(6374), np.int64(11628)) (distance: 0, flex_idx: 6352, parflex_idx: 5781)
#   Intersection 351: (np.int64(6948), np.int64(12556)) (distance: 0, flex_idx: 6926, parflex_idx: 6355)
#   Intersection 352: (np.int64(6475), np.int64(11778)) (distance: 0, flex_idx: 6453, parflex_idx: 5882)
#   Intersection 353: (np.int64(6807), np.int64(12288)) (distance: 0, flex_idx: 6785, parflex_idx: 6214)
#   Intersection 354: (np.int64(6872), np.int64(12408)) (distance: 0, flex_idx: 6850, parflex_idx: 6279)
#   Intersection 355: (np.int64(6396), np.int64(11652)) (distance: 0, flex_idx: 6374, parflex_idx: 5803)
#   Intersection 356: (np.int64(6439), np.int64(11721)) (distance: 0, flex_idx: 6417, parflex_idx: 5846)
#   Intersection 357: (np.int64(6407), np.int64(11670)) (distance: 0, flex_idx: 6385, parflex_idx: 5814)
#   Intersection 358: (np.int64(6693), np.int64(12113)) (distance: 0, flex_idx: 6671, parflex_idx: 6100)
#   Intersection 359: (np.int64(6965), np.int64(12590)) (distance: 0, flex_idx: 6943, parflex_idx: 6372)
#   Intersection 360: (np.int64(6889), np.int64(12442)) (distance: 0, flex_idx: 6867, parflex_idx: 6296)
#   Intersection 361: (np.int64(6741), np.int64(12189)) (distance: 0, flex_idx: 6719, parflex_idx: 6148)
#   Intersection 362: (np.int64(6694), np.int64(12114)) (distance: 0, flex_idx: 6672, parflex_idx: 6101)
#   Intersection 363: (np.int64(6918), np.int64(12496)) (distance: 0, flex_idx: 6896, parflex_idx: 6325)
#   Intersection 364: (np.int64(6936), np.int64(12532)) (distance: 0, flex_idx: 6914, parflex_idx: 6343)
#   Intersection 365: (np.int64(6821), np.int64(12316)) (distance: 0, flex_idx: 6799, parflex_idx: 6228)
#   Intersection 366: (np.int64(6795), np.int64(12264)) (distance: 0, flex_idx: 6773, parflex_idx: 6202)
#   Intersection 367: (np.int64(6366), np.int64(11619)) (distance: 0, flex_idx: 6344, parflex_idx: 5773)
#   Intersection 368: (np.int64(6748), np.int64(12197)) (distance: 0, flex_idx: 6726, parflex_idx: 6155)
#   Intersection 369: (np.int64(6953), np.int64(12566)) (distance: 0, flex_idx: 6931, parflex_idx: 6360)
#   Intersection 370: (np.int64(6788), np.int64(12251)) (distance: 0, flex_idx: 6766, parflex_idx: 6195)
#   Intersection 371: (np.int64(6708), np.int64(12142)) (distance: 0, flex_idx: 6686, parflex_idx: 6115)
#   Intersection 372: (np.int64(6950), np.int64(12560)) (distance: 0, flex_idx: 6928, parflex_idx: 6357)
#   Intersection 373: (np.int64(6809), np.int64(12292)) (distance: 0, flex_idx: 6787, parflex_idx: 6216)
#   Intersection 374: (np.int64(6857), np.int64(12378)) (distance: 0, flex_idx: 6835, parflex_idx: 6264)
#   Intersection 375: (np.int64(6749), np.int64(12198)) (distance: 0, flex_idx: 6727, parflex_idx: 6156)
#   Intersection 376: (np.int64(6846), np.int64(12359)) (distance: 0, flex_idx: 6824, parflex_idx: 6253)
#   Intersection 377: (np.int64(6428), np.int64(11706)) (distance: 0, flex_idx: 6406, parflex_idx: 5835)
#   Intersection 378: (np.int64(6457), np.int64(11751)) (distance: 0, flex_idx: 6435, parflex_idx: 5864)
#   Intersection 379: (np.int64(6373), np.int64(11627)) (distance: 0, flex_idx: 6351, parflex_idx: 5780)
#   Intersection 380: (np.int64(6410), np.int64(11676)) (distance: 0, flex_idx: 6388, parflex_idx: 5817)
#   Intersection 381: (np.int64(6947), np.int64(12554)) (distance: 0, flex_idx: 6925, parflex_idx: 6354)
#   Intersection 382: (np.int64(6755), np.int64(12204)) (distance: 0, flex_idx: 6733, parflex_idx: 6162)
#   Intersection 383: (np.int64(6824), np.int64(12322)) (distance: 0, flex_idx: 6802, parflex_idx: 6231)
#   Intersection 384: (np.int64(6871), np.int64(12406)) (distance: 0, flex_idx: 6849, parflex_idx: 6278)
#   Intersection 385: (np.int64(6395), np.int64(11650)) (distance: 0, flex_idx: 6373, parflex_idx: 5802)
#   Intersection 386: (np.int64(6403), np.int64(11663)) (distance: 0, flex_idx: 6381, parflex_idx: 5810)
#   Intersection 387: (np.int64(6756), np.int64(12205)) (distance: 0, flex_idx: 6734, parflex_idx: 6163)
#   Intersection 388: (np.int64(6737), np.int64(12182)) (distance: 0, flex_idx: 6715, parflex_idx: 6144)
#   Intersection 389: (np.int64(6380), np.int64(11634)) (distance: 0, flex_idx: 6358, parflex_idx: 5787)
#   Intersection 390: (np.int64(6711), np.int64(12148)) (distance: 0, flex_idx: 6689, parflex_idx: 6118)
#   Intersection 391: (np.int64(6935), np.int64(12530)) (distance: 0, flex_idx: 6913, parflex_idx: 6342)
#   Intersection 392: (np.int64(6886), np.int64(12436)) (distance: 0, flex_idx: 6864, parflex_idx: 6293)
#   Intersection 393: (np.int64(6722), np.int64(12166)) (distance: 0, flex_idx: 6700, parflex_idx: 6129)
#   Intersection 394: (np.int64(6381), np.int64(11635)) (distance: 0, flex_idx: 6359, parflex_idx: 5788)
#   Intersection 395: (np.int64(6762), np.int64(12211)) (distance: 0, flex_idx: 6740, parflex_idx: 6169)
#   Intersection 396: (np.int64(6915), np.int64(12490)) (distance: 0, flex_idx: 6893, parflex_idx: 6322)
#   Intersection 397: (np.int64(6431), np.int64(11712)) (distance: 0, flex_idx: 6409, parflex_idx: 5838)
#   Intersection 398: (np.int64(6460), np.int64(11757)) (distance: 0, flex_idx: 6438, parflex_idx: 5867)
#   Intersection 399: (np.int64(6839), np.int64(12351)) (distance: 0, flex_idx: 6817, parflex_idx: 6246)
#   Intersection 400: (np.int64(6763), np.int64(12212)) (distance: 0, flex_idx: 6741, parflex_idx: 6170)
#   Intersection 401: (np.int64(6845), np.int64(12358)) (distance: 0, flex_idx: 6823, parflex_idx: 6252)
#   Intersection 402: (np.int64(6853), np.int64(12371)) (distance: 0, flex_idx: 6831, parflex_idx: 6260)
#   Intersection 403: (np.int64(6932), np.int64(12524)) (distance: 0, flex_idx: 6910, parflex_idx: 6339)
#   Intersection 404: (np.int64(6387), np.int64(11641)) (distance: 0, flex_idx: 6365, parflex_idx: 5794)
#   Intersection 405: (np.int64(6856), np.int64(12376)) (distance: 0, flex_idx: 6834, parflex_idx: 6263)
#   Intersection 406: (np.int64(6874), np.int64(12412)) (distance: 0, flex_idx: 6852, parflex_idx: 6281)
#   Intersection 407: (np.int64(6777), np.int64(12232)) (distance: 0, flex_idx: 6755, parflex_idx: 6184)
#   Intersection 408: (np.int64(6929), np.int64(12518)) (distance: 0, flex_idx: 6907, parflex_idx: 6336)
#   Intersection 409: (np.int64(6398), np.int64(11656)) (distance: 0, flex_idx: 6376, parflex_idx: 5805)
#   Intersection 410: (np.int64(6806), np.int64(12286)) (distance: 0, flex_idx: 6784, parflex_idx: 6213)
#   Intersection 411: (np.int64(6729), np.int64(12173)) (distance: 0, flex_idx: 6707, parflex_idx: 6136)
#   Intersection 412: (np.int64(6388), np.int64(11642)) (distance: 0, flex_idx: 6366, parflex_idx: 5795)
#   Intersection 413: (np.int64(6849), np.int64(12364)) (distance: 0, flex_idx: 6827, parflex_idx: 6256)
#   Intersection 414: (np.int64(6409), np.int64(11674)) (distance: 0, flex_idx: 6387, parflex_idx: 5816)
#   Intersection 415: (np.int64(6438), np.int64(11719)) (distance: 0, flex_idx: 6416, parflex_idx: 5845)
#   Intersection 416: (np.int64(6449), np.int64(11737)) (distance: 0, flex_idx: 6427, parflex_idx: 5856)
#   Intersection 417: (np.int64(6730), np.int64(12174)) (distance: 0, flex_idx: 6708, parflex_idx: 6137)
#   Intersection 418: (np.int64(6394), np.int64(11649)) (distance: 0, flex_idx: 6372, parflex_idx: 5801)
#   Intersection 419: (np.int64(6402), np.int64(11662)) (distance: 0, flex_idx: 6380, parflex_idx: 5809)
#   Intersection 420: (np.int64(6946), np.int64(12552)) (distance: 0, flex_idx: 6924, parflex_idx: 6353)
#   Intersection 421: (np.int64(6964), np.int64(12588)) (distance: 0, flex_idx: 6942, parflex_idx: 6371)
#   Intersection 422: (np.int64(6823), np.int64(12320)) (distance: 0, flex_idx: 6801, parflex_idx: 6230)
#   Intersection 423: (np.int64(6888), np.int64(12440)) (distance: 0, flex_idx: 6866, parflex_idx: 6295)
#   Intersection 424: (np.int64(6413), np.int64(11680)) (distance: 0, flex_idx: 6391, parflex_idx: 5820)
#   Intersection 425: (np.int64(6917), np.int64(12494)) (distance: 0, flex_idx: 6895, parflex_idx: 6324)
#   Intersection 426: (np.int64(6675), np.int64(12094)) (distance: 0, flex_idx: 6653, parflex_idx: 6082)
#   Intersection 427: (np.int64(6681), np.int64(12101)) (distance: 0, flex_idx: 6659, parflex_idx: 6088)
#   Intersection 428: (np.int64(6740), np.int64(12187)) (distance: 0, flex_idx: 6718, parflex_idx: 6147)
#   Intersection 429: (np.int64(6365), np.int64(11617)) (distance: 0, flex_idx: 6343, parflex_idx: 5772)
#   Intersection 430: (np.int64(6710), np.int64(12146)) (distance: 0, flex_idx: 6688, parflex_idx: 6117)
#   Intersection 431: (np.int64(6885), np.int64(12434)) (distance: 0, flex_idx: 6863, parflex_idx: 6292)
#   Intersection 432: (np.int64(6345), np.int64(11578)) (distance: 2, flex_idx: 6323, parflex_idx: 5750)
#   Intersection 433: (np.int64(6346), np.int64(11580)) (distance: 1, flex_idx: 6324, parflex_idx: 5752)
#   Intersection 434: (np.int64(6347), np.int64(11582)) (distance: 1, flex_idx: 6325, parflex_idx: 5753)
#   Intersection 435: (np.int64(6348), np.int64(11584)) (distance: 1, flex_idx: 6326, parflex_idx: 5754)
#   Intersection 436: (np.int64(6349), np.int64(11586)) (distance: 1, flex_idx: 6327, parflex_idx: 5755)
#   Intersection 437: (np.int64(6350), np.int64(11588)) (distance: 1, flex_idx: 6328, parflex_idx: 5756)
#   Intersection 438: (np.int64(6351), np.int64(11590)) (distance: 1, flex_idx: 6329, parflex_idx: 5757)
#   Intersection 439: (np.int64(6352), np.int64(11592)) (distance: 1, flex_idx: 6330, parflex_idx: 5758)
#   Intersection 440: (np.int64(6353), np.int64(11594)) (distance: 1, flex_idx: 6331, parflex_idx: 5759)
#   Intersection 441: (np.int64(6354), np.int64(11596)) (distance: 1, flex_idx: 6332, parflex_idx: 5760)
#   Intersection 442: (np.int64(6355), np.int64(11598)) (distance: 1, flex_idx: 6333, parflex_idx: 5761)
#   Intersection 443: (np.int64(6356), np.int64(11600)) (distance: 2, flex_idx: 6334, parflex_idx: 5762)
#   Intersection 444: (np.int64(6487), np.int64(11801)) (distance: 2, flex_idx: 6465, parflex_idx: 5893)
#   Intersection 445: (np.int64(6488), np.int64(11802)) (distance: 1, flex_idx: 6466, parflex_idx: 5894)
#   Intersection 446: (np.int64(6489), np.int64(11803)) (distance: 1, flex_idx: 6467, parflex_idx: 5895)
#   Intersection 447: (np.int64(6490), np.int64(11804)) (distance: 1, flex_idx: 6468, parflex_idx: 5896)
#   Intersection 448: (np.int64(6491), np.int64(11805)) (distance: 1, flex_idx: 6469, parflex_idx: 5897)
#   Intersection 449: (np.int64(6492), np.int64(11806)) (distance: 2, flex_idx: 6470, parflex_idx: 5898)
#   Intersection 450: (np.int64(6493), np.int64(11808)) (distance: 2, flex_idx: 6471, parflex_idx: 5899)
#   Intersection 451: (np.int64(6494), np.int64(11809)) (distance: 2, flex_idx: 6472, parflex_idx: 5899)
#   Intersection 452: (np.int64(6651), np.int64(12061)) (distance: 2, flex_idx: 6629, parflex_idx: 6056)
#   Intersection 453: (np.int64(6652), np.int64(12063)) (distance: 2, flex_idx: 6630, parflex_idx: 6057)
#   Intersection 454: (np.int64(6658), np.int64(12070)) (distance: 2, flex_idx: 6636, parflex_idx: 6063)
#   Intersection 455: (np.int64(6659), np.int64(12072)) (distance: 2, flex_idx: 6637, parflex_idx: 6065)
#   Intersection 456: (np.int64(6660), np.int64(12073)) (distance: 2, flex_idx: 6638, parflex_idx: 6065)
#   Intersection 457: (np.int64(6662), np.int64(12076)) (distance: 2, flex_idx: 6640, parflex_idx: 6067)
#   Intersection 458: (np.int64(6663), np.int64(12078)) (distance: 2, flex_idx: 6641, parflex_idx: 6068)
#   Intersection 459: (np.int64(6664), np.int64(12080)) (distance: 2, flex_idx: 6642, parflex_idx: 6069)
#   Intersection 460: (np.int64(6665), np.int64(12082)) (distance: 1, flex_idx: 6643, parflex_idx: 6071)
#   Intersection 461: (np.int64(6666), np.int64(12083)) (distance: 1, flex_idx: 6644, parflex_idx: 6072)
#   Intersection 462: (np.int64(6667), np.int64(12084)) (distance: 1, flex_idx: 6645, parflex_idx: 6073)
#   Intersection 463: (np.int64(6668), np.int64(12086)) (distance: 1, flex_idx: 6646, parflex_idx: 6074)
#   Intersection 464: (np.int64(6669), np.int64(12087)) (distance: 1, flex_idx: 6647, parflex_idx: 6075)
#   Intersection 465: (np.int64(6670), np.int64(12088)) (distance: 1, flex_idx: 6648, parflex_idx: 6076)
#   Intersection 466: (np.int64(6671), np.int64(12089)) (distance: 1, flex_idx: 6649, parflex_idx: 6077)
#   Intersection 467: (np.int64(6672), np.int64(12090)) (distance: 1, flex_idx: 6650, parflex_idx: 6078)
#   Intersection 468: (np.int64(6673), np.int64(12091)) (distance: 1, flex_idx: 6651, parflex_idx: 6079)
#   Intersection 469: (np.int64(6674), np.int64(12092)) (distance: 1, flex_idx: 6652, parflex_idx: 6080)
#   Intersection 470: (np.int64(6976), np.int64(12612)) (distance: 1, flex_idx: 6954, parflex_idx: 6383)
#   Intersection 471: (np.int64(6977), np.int64(12614)) (distance: 2, flex_idx: 6955, parflex_idx: 6384)
#   Intersection 472: (np.int64(6978), np.int64(12616)) (distance: 2, flex_idx: 6956, parflex_idx: 6386)
#   Intersection 473: (np.int64(6979), np.int64(12618)) (distance: 2, flex_idx: 6957, parflex_idx: 6387)
#   Intersection 474: (np.int64(6980), np.int64(12620)) (distance: 2, flex_idx: 6958, parflex_idx: 6388)
#   Intersection 475: (np.int64(6981), np.int64(12622)) (distance: 2, flex_idx: 6959, parflex_idx: 6389)
#   Intersection 476: (np.int64(6982), np.int64(12624)) (distance: 2, flex_idx: 6960, parflex_idx: 6390)
#   Intersection 477: (np.int64(6983), np.int64(12626)) (distance: 2, flex_idx: 6961, parflex_idx: 6391)
#   Intersection 478: (np.int64(6984), np.int64(12628)) (distance: 2, flex_idx: 6962, parflex_idx: 6392)
#   Intersection 479: (np.int64(6985), np.int64(12630)) (distance: 2, flex_idx: 6963, parflex_idx: 6393)
#   Intersection 480: (np.int64(6986), np.int64(12632)) (distance: 2, flex_idx: 6964, parflex_idx: 6394)
#   Intersection 481: (np.int64(6987), np.int64(12634)) (distance: 2, flex_idx: 6965, parflex_idx: 6395)
#   Intersection 482: (np.int64(6988), np.int64(12636)) (distance: 2, flex_idx: 6966, parflex_idx: 6396)
#   Intersection 483: (np.int64(6989), np.int64(12638)) (distance: 2, flex_idx: 6967, parflex_idx: 6397)
#   Intersection 484: (np.int64(6990), np.int64(12640)) (distance: 2, flex_idx: 6968, parflex_idx: 6398)
#   Intersection 485: (np.int64(6991), np.int64(12642)) (distance: 2, flex_idx: 6969, parflex_idx: 6399)
#   Intersection 486: (np.int64(6992), np.int64(12644)) (distance: 2, flex_idx: 6970, parflex_idx: 6400)
#   Intersection 487: (np.int64(6993), np.int64(12646)) (distance: 2, flex_idx: 6971, parflex_idx: 6401)
#   Intersection 488: (np.int64(6994), np.int64(12648)) (distance: 2, flex_idx: 6972, parflex_idx: 6402)
#   Intersection 489: (np.int64(6995), np.int64(12650)) (distance: 2, flex_idx: 6973, parflex_idx: 6403)
#   Intersection 490: (np.int64(6996), np.int64(12652)) (distance: 2, flex_idx: 6974, parflex_idx: 6404)
#   Intersection 491: (np.int64(6997), np.int64(12654)) (distance: 2, flex_idx: 6975, parflex_idx: 6405)
#   Intersection 492: (np.int64(6998), np.int64(12656)) (distance: 2, flex_idx: 6976, parflex_idx: 6406)
#   Intersection 493: (np.int64(6999), np.int64(12658)) (distance: 2, flex_idx: 6977, parflex_idx: 6407)
#   Intersection 494: (np.int64(7000), np.int64(12660)) (distance: 2, flex_idx: 6978, parflex_idx: 6408)
#   Intersection 495: (np.int64(7001), np.int64(12662)) (distance: 2, flex_idx: 6979, parflex_idx: 6409)
#   Intersection 496: (np.int64(7002), np.int64(12664)) (distance: 2, flex_idx: 6980, parflex_idx: 6410)
#   Intersection 497: (np.int64(7003), np.int64(12666)) (distance: 2, flex_idx: 6981, parflex_idx: 6411)
#   Intersection 498: (np.int64(7004), np.int64(12668)) (distance: 2, flex_idx: 6982, parflex_idx: 6412)
#   Intersection 499: (np.int64(7005), np.int64(12670)) (distance: 2, flex_idx: 6983, parflex_idx: 6413)
#   Intersection 500: (np.int64(7006), np.int64(12672)) (distance: 2, flex_idx: 6984, parflex_idx: 6414)
#   Intersection 501: (np.int64(7007), np.int64(12674)) (distance: 2, flex_idx: 6985, parflex_idx: 6415)
#   Intersection 502: (np.int64(7008), np.int64(12676)) (distance: 2, flex_idx: 6986, parflex_idx: 6416)
#   Intersection 503: (np.int64(7009), np.int64(12678)) (distance: 2, flex_idx: 6987, parflex_idx: 6417)
#   Intersection 504: (np.int64(7010), np.int64(12680)) (distance: 2, flex_idx: 6988, parflex_idx: 6418)
#   Intersection 505: (np.int64(7011), np.int64(12682)) (distance: 2, flex_idx: 6989, parflex_idx: 6419)
#   Intersection 506: (np.int64(7012), np.int64(12684)) (distance: 2, flex_idx: 6990, parflex_idx: 6420)
#   Intersection 507: (np.int64(7013), np.int64(12686)) (distance: 2, flex_idx: 6991, parflex_idx: 6421)
#   Intersection 508: (np.int64(7014), np.int64(12688)) (distance: 2, flex_idx: 6992, parflex_idx: 6422)
#   Intersection 509: (np.int64(7015), np.int64(12690)) (distance: 2, flex_idx: 6993, parflex_idx: 6423)
#   Intersection 510: (np.int64(7016), np.int64(12692)) (distance: 2, flex_idx: 6994, parflex_idx: 6424)
#   Intersection 511: (np.int64(7017), np.int64(12694)) (distance: 2, flex_idx: 6995, parflex_idx: 6425)
#   Intersection 512: (np.int64(7018), np.int64(12696)) (distance: 2, flex_idx: 6996, parflex_idx: 6426)
#   Intersection 513: (np.int64(7019), np.int64(12698)) (distance: 2, flex_idx: 6997, parflex_idx: 6427)
#   Intersection 514: (np.int64(7020), np.int64(12700)) (distance: 2, flex_idx: 6998, parflex_idx: 6428)
#   Intersection 515: (np.int64(7021), np.int64(12702)) (distance: 2, flex_idx: 6999, parflex_idx: 6429)
#   Intersection 516: (np.int64(7022), np.int64(12704)) (distance: 2, flex_idx: 7000, parflex_idx: 6430)
#   Intersection 517: (np.int64(7023), np.int64(12706)) (distance: 2, flex_idx: 7001, parflex_idx: 6431)
#   Intersection 518: (np.int64(7024), np.int64(12708)) (distance: 2, flex_idx: 7002, parflex_idx: 6432)
#   Intersection 519: (np.int64(7025), np.int64(12710)) (distance: 2, flex_idx: 7003, parflex_idx: 6433)
#   Intersection 520: (np.int64(7026), np.int64(12712)) (distance: 2, flex_idx: 7004, parflex_idx: 6434)
#   Intersection 521: (np.int64(7027), np.int64(12714)) (distance: 2, flex_idx: 7005, parflex_idx: 6435)
#   Intersection 522: (np.int64(7028), np.int64(12716)) (distance: 2, flex_idx: 7006, parflex_idx: 6436)
#   Intersection 523: (np.int64(7029), np.int64(12718)) (distance: 2, flex_idx: 7007, parflex_idx: 6437)
#   Intersection 524: (np.int64(7030), np.int64(12720)) (distance: 2, flex_idx: 7008, parflex_idx: 6438)
#   Intersection 525: (np.int64(7031), np.int64(12722)) (distance: 2, flex_idx: 7009, parflex_idx: 6439)
#   Intersection 526: (np.int64(7032), np.int64(12724)) (distance: 2, flex_idx: 7010, parflex_idx: 6440)
#   Intersection 527: (np.int64(7033), np.int64(12726)) (distance: 2, flex_idx: 7011, parflex_idx: 6441)
#   Intersection 528: (np.int64(7034), np.int64(12728)) (distance: 2, flex_idx: 7012, parflex_idx: 6442)
#   Intersection 529: (np.int64(7035), np.int64(12730)) (distance: 2, flex_idx: 7013, parflex_idx: 6443)
#   Intersection 530: (np.int64(7036), np.int64(12732)) (distance: 2, flex_idx: 7014, parflex_idx: 6444)
#   Intersection 531: (np.int64(7037), np.int64(12734)) (distance: 2, flex_idx: 7015, parflex_idx: 6445)
#   Intersection 532: (np.int64(7038), np.int64(12736)) (distance: 2, flex_idx: 7016, parflex_idx: 6446)

# %% [markdown]
# ## 4. Cost Matrix Neighborhood Analysis

# %%
def extract_cost_neighborhood(C, center_row, center_col, radius=50):
    """
    Extract a submatrix around a center point.
    
    Parameters:
    -----------
    C : ndarray
        Cost matrix
    center_row, center_col : int
        Center coordinates
    radius : int
        Radius of neighborhood
        
    Returns:
    --------
    C_local : ndarray
        Local cost matrix
    row_range : tuple
        (start_row, end_row) in global coordinates
    col_range : tuple
        (start_col, end_col) in global coordinates
    """
    L1, L2 = C.shape
    
    # Calculate bounds
    row_start = max(0, center_row - radius)
    row_end = min(L1, center_row + radius + 1)
    col_start = max(0, center_col - radius)
    col_end = min(L2, center_col + radius + 1)
    
    # Extract submatrix
    C_local = C[row_start:row_end, col_start:col_end].copy()
    
    return C_local, (row_start, row_end), (col_start, col_end)

def map_path_to_local(wp, row_start, row_end, col_start, col_end):
    """
    Map a global warping path to local coordinates.
    
    Parameters:
    -----------
    wp : ndarray, shape (N, 2)
        Global warping path
    row_start, row_end, col_start, col_end : int
        Bounds of local region
        
    Returns:
    --------
    wp_local : ndarray
        Local path (points outside region are filtered out)
    valid_mask : ndarray
        Boolean mask indicating which points are in the local region
    """
    wp = np.asarray(wp)
    valid_mask = ((wp[:, 0] >= row_start) & (wp[:, 0] < row_end) &
                  (wp[:, 1] >= col_start) & (wp[:, 1] < col_end))
    
    wp_local = wp[valid_mask].copy()
    wp_local[:, 0] -= row_start
    wp_local[:, 1] -= col_start
    
    return wp_local, valid_mask

def find_divergence_point(wp1, wp2, intersection_idx1, intersection_idx2):
    """
    Find the first point after intersection where paths diverge.
    
    Parameters:
    -----------
    wp1, wp2 : ndarray, shape (N, 2)
        Warping paths
    intersection_idx1, intersection_idx2 : int
        Indices of intersection point in each path
        
    Returns:
    --------
    divergence_idx1, divergence_idx2 : int
        Indices where paths diverge (or None if they don't diverge)
    divergence_point : tuple
        Coordinates of divergence point
    """
    # Start searching after intersection
    start_idx1 = intersection_idx1 + 1
    start_idx2 = intersection_idx2 + 1
    
    # Find minimum length to check
    min_len = min(len(wp1) - start_idx1, len(wp2) - start_idx2)
    
    for i in range(min_len):
        idx1 = start_idx1 + i
        idx2 = start_idx2 + i
        
        p1 = tuple(wp1[idx1])
        p2 = tuple(wp2[idx2])
        
        if p1 != p2:
            return idx1, idx2, p1
    
    # Paths don't diverge (one ends)
    return None, None, None

# %% [markdown]
# ## 5. Chunk Boundary Analysis

# %%
def identify_chunk_at_point(tiled_result, row, col):
    """
    Identify which chunk contains a given point.
    
    Parameters:
    -----------
    tiled_result : dict
        Result from Parflex.align_system_parflex
    row, col : int
        Global coordinates
        
    Returns:
    --------
    chunk_info : dict or None
        Dictionary with:
        - 'chunk': (i, j) chunk indices
        - 'local_row', 'local_col': local coordinates within chunk
        - 'bounds': (row_start, row_end, col_start, col_end)
        - 'block': block dictionary from tiled_result
    """
    blocks = tiled_result['blocks']
    
    for block in blocks:
        r_start, r_end = block['rows']
        c_start, c_end = block['cols']
        
        if r_start <= row < r_end and c_start <= col < c_end:
            local_row = row - r_start
            local_col = col - c_start
            
            return {
                'chunk': (block['bi'], block['bj']),
                'local_row': local_row,
                'local_col': local_col,
                'bounds': (r_start, r_end, c_start, c_end),
                'block': block
            }
    
    return None

def analyze_chunk_contribution(chunks_dict, chunk_i, chunk_j, intersection_point):
    """
    Analyze how chunk contributes to path cost at intersection point.
    
    Parameters:
    -----------
    chunks_dict : dict
        Dictionary from chunk_flexdtw
    chunk_i, chunk_j : int
        Chunk indices
    intersection_point : tuple
        (row, col) in global coordinates
        
    Returns:
    --------
    analysis : dict
        Analysis results
    """
    chunk_key = (chunk_i, chunk_j)
    if chunk_key not in chunks_dict:
        return None
    
    chunk_data = chunks_dict[chunk_key]
    start_1, end_1, start_2, end_2 = chunk_data['bounds']
    
    # Convert to local coordinates
    local_row = intersection_point[0] - start_1
    local_col = intersection_point[1] - start_2
    
    # Get chunk matrices
    D_chunk = chunk_data['D']
    S_chunk = chunk_data['S']
    B_chunk = chunk_data['B']
    C_chunk = chunk_data.get('C', None)
    
    analysis = {
        'chunk': chunk_key,
        'local_coords': (local_row, local_col),
        'global_coords': intersection_point,
        'bounds': (start_1, end_1, start_2, end_2),
        'D_value': D_chunk[local_row, local_col] if (0 <= local_row < D_chunk.shape[0] and 
                                                      0 <= local_col < D_chunk.shape[1]) else None,
        'S_value': S_chunk[local_row, local_col] if (0 <= local_row < S_chunk.shape[0] and 
                                                      0 <= local_col < S_chunk.shape[1]) else None,
        'B_value': B_chunk[local_row, local_col] if (0 <= local_row < B_chunk.shape[0] and 
                                                      0 <= local_col < B_chunk.shape[1]) else None,
        'C_value': C_chunk[local_row, local_col] if (C_chunk is not None and 
                                                      0 <= local_row < C_chunk.shape[0] and 
                                                      0 <= local_col < C_chunk.shape[1]) else None,
    }
    
    return analysis

# %% [markdown]
# ## 6. Visualization Functions

# %%
def plot_cost_matrix_with_paths(C_local, wp1_local, wp2_local, intersection_point_local, 
                                 divergence_point_local, row_range, col_range, title="Cost Matrix with Paths"):
    """
    Create heatmap of cost matrix with overlaid paths.
    
    Parameters:
    -----------
    C_local : ndarray
        Local cost matrix
    wp1_local, wp2_local : ndarray
        Local warping paths
    intersection_point_local : tuple
        (row, col) in local coordinates
    divergence_point_local : tuple or None
        (row, col) in local coordinates
    row_range, col_range : tuple
        (start, end) ranges for axis labels
    title : str
        Plot title
    """
    fig, ax = plt.subplots(figsize=(12, 10))
    
    # Plot cost matrix heatmap
    im = ax.imshow(C_local, cmap='viridis', aspect='auto', origin='lower')
    plt.colorbar(im, ax=ax, label='Cost')
    
    # Plot paths
    if len(wp1_local) > 0:
        ax.plot(wp1_local[:, 1], wp1_local[:, 0], 'b-', linewidth=2, alpha=0.7, 
                label='FlexDTW', marker='o', markersize=3)
    if len(wp2_local) > 0:
        ax.plot(wp2_local[:, 1], wp2_local[:, 0], 'r-', linewidth=2, alpha=0.7, 
                label='Parflex', marker='s', markersize=3)
    
    # Mark intersection point
    if intersection_point_local:
        inter_row, inter_col = intersection_point_local
        ax.plot(inter_col, inter_row, 'go', markersize=15, label='Intersection', 
                markeredgecolor='black', markeredgewidth=2)
        # Add cost annotation
        if 0 <= inter_row < C_local.shape[0] and 0 <= inter_col < C_local.shape[1]:
            cost_val = C_local[inter_row, inter_col]
            ax.annotate(f'C={cost_val:.3f}', 
                       xy=(inter_col, inter_row), 
                       xytext=(10, 10), textcoords='offset points',
                       bbox=dict(boxstyle='round,pad=0.3', facecolor='yellow', alpha=0.7),
                       fontsize=10)
    
    # Mark divergence point
    if divergence_point_local:
        div_row, div_col = divergence_point_local
        ax.plot(div_col, div_row, 'ro', markersize=15, label='Divergence', 
                markeredgecolor='black', markeredgewidth=2)
        # Add cost annotation
        if 0 <= div_row < C_local.shape[0] and 0 <= div_col < C_local.shape[1]:
            cost_val = C_local[div_row, div_col]
            ax.annotate(f'C={cost_val:.3f}', 
                       xy=(div_col, div_row), 
                       xytext=(10, -20), textcoords='offset points',
                       bbox=dict(boxstyle='round,pad=0.3', facecolor='orange', alpha=0.7),
                       fontsize=10)
    
    ax.set_xlabel('Column (F2 frames)', fontsize=12)
    ax.set_ylabel('Row (F1 frames)', fontsize=12)
    ax.set_title(title, fontsize=14, fontweight='bold')
    ax.legend(loc='upper right', fontsize=10)
    ax.grid(True, alpha=0.3)
    
    # Set axis labels to global coordinates
    row_start, row_end = row_range
    col_start, col_end = col_range
    
    # Set ticks to show global coordinates
    n_ticks = 5
    row_ticks = np.linspace(0, C_local.shape[0]-1, n_ticks).astype(int)
    col_ticks = np.linspace(0, C_local.shape[1]-1, n_ticks).astype(int)
    
    ax.set_yticks(row_ticks)
    ax.set_yticklabels([row_start + r for r in row_ticks])
    ax.set_xticks(col_ticks)
    ax.set_xticklabels([col_start + c for c in col_ticks])
    
    plt.tight_layout()
    return fig, ax

# %%
def plot_path_comparison_zoom(C, wp_flex, wp_parflex, intersection_point, window_size=100):
    """
    Create zoomed-in view around intersection with both paths.
    
    Parameters:
    -----------
    C : ndarray
        Full cost matrix
    wp_flex, wp_parflex : ndarray
        Warping paths
    intersection_point : tuple
        (row, col) global coordinates
    window_size : int
        Size of window around intersection
    """
    inter_row, inter_col = intersection_point
    
    # Extract neighborhood
    C_local, row_range, col_range = extract_cost_neighborhood(
        C, inter_row, inter_col, radius=window_size//2
    )
    
    # Map paths to local
    wp_flex_local, _ = map_path_to_local(wp_flex, *row_range, *col_range)
    wp_parflex_local, _ = map_path_to_local(wp_parflex, *row_range, *col_range)
    
    # Local intersection point
    inter_local = (inter_row - row_range[0], inter_col - col_range[0])
    
    # Find divergence
    intersections = find_path_intersections(wp_flex, wp_parflex, tolerance=2)
    if intersections:
        inter = intersections[0]
        div_idx1, div_idx2, div_point = find_divergence_point(
            wp_flex, wp_parflex, inter['idx1'], inter['idx2']
        )
        if div_point:
            div_local = (div_point[0] - row_range[0], div_point[1] - col_range[0])
        else:
            div_local = None
    else:
        div_local = None
    
    # Plot
    fig, ax = plot_cost_matrix_with_paths(
        C_local, wp_flex_local, wp_parflex_local, inter_local, div_local,
        row_range, col_range, 
        title=f"Zoomed View Around Intersection {intersection_point}"
    )
    
    return fig, ax

# %%
def plot_divergence_analysis(C, D_flex, B_flex, wp_flex, wp_parflex, 
                              intersection_idx, divergence_idx, radius=30):
    """
    Visualize divergence point with backpointer analysis.
    
    Parameters:
    -----------
    C, D_flex, B_flex : ndarray
        Cost, accumulated cost, and backpointer matrices
    wp_flex, wp_parflex : ndarray
        Warping paths
    intersection_idx : int
        Index of intersection in wp_flex
    divergence_idx : int
        Index of divergence in wp_flex
    radius : int
        Radius around divergence point
    """
    if divergence_idx is None:
        print("No divergence found")
        return None
    
    div_point = wp_flex[divergence_idx]
    div_row, div_col = div_point
    
    # Extract neighborhood
    C_local, row_range, col_range = extract_cost_neighborhood(
        C, div_row, div_col, radius=radius
    )
    
    # Extract D and B neighborhoods
    D_local = D_flex[row_range[0]:row_range[1], col_range[0]:col_range[1]]
    B_local = B_flex[row_range[0]:row_range[1], col_range[0]:col_range[1]]
    
    # Map paths to local
    wp_flex_local, _ = map_path_to_local(wp_flex, *row_range, *col_range)
    wp_parflex_local, _ = map_path_to_local(wp_parflex, *row_range, *col_range)
    
    # Local divergence point
    div_local = (div_row - row_range[0], div_col - col_range[0])
    
    # Create figure with subplots
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    
    # Plot 1: Cost matrix
    im1 = axes[0].imshow(C_local, cmap='viridis', aspect='auto', origin='lower')
    axes[0].plot(wp_flex_local[:, 1], wp_flex_local[:, 0], 'b-', linewidth=2, alpha=0.7, label='FlexDTW')
    axes[0].plot(wp_parflex_local[:, 1], wp_parflex_local[:, 0], 'r-', linewidth=2, alpha=0.7, label='Parflex')
    axes[0].plot(div_local[1], div_local[0], 'ro', markersize=15, markeredgecolor='black', markeredgewidth=2)
    axes[0].set_title('Cost Matrix C', fontsize=12, fontweight='bold')
    axes[0].set_xlabel('Column')
    axes[0].set_ylabel('Row')
    axes[0].legend()
    plt.colorbar(im1, ax=axes[0])
    
    # Plot 2: Accumulated cost D
    im2 = axes[1].imshow(D_local, cmap='plasma', aspect='auto', origin='lower')
    axes[1].plot(wp_flex_local[:, 1], wp_flex_local[:, 0], 'b-', linewidth=2, alpha=0.7)
    axes[1].plot(wp_parflex_local[:, 1], wp_parflex_local[:, 0], 'r-', linewidth=2, alpha=0.7)
    axes[1].plot(div_local[1], div_local[0], 'ro', markersize=15, markeredgecolor='black', markeredgewidth=2)
    axes[1].set_title('Accumulated Cost D (FlexDTW)', fontsize=12, fontweight='bold')
    axes[1].set_xlabel('Column')
    axes[1].set_ylabel('Row')
    plt.colorbar(im2, ax=axes[1])
    
    # Plot 3: Backpointer visualization
    axes[2].imshow(C_local, cmap='gray', aspect='auto', origin='lower', alpha=0.5)
    
    # Draw arrows for backpointers around divergence point
    steps = np.array([[1, 1], [1, 2], [2, 1]])
    div_row_local, div_col_local = div_local
    
    # Check backpointer at divergence point
    if 0 <= div_row_local < B_local.shape[0] and 0 <= div_col_local < B_local.shape[1]:
        bp_idx = int(B_local[div_row_local, div_col_local])
        if 0 <= bp_idx < len(steps):
            step = steps[bp_idx]
            # Draw arrow showing where FlexDTW came from
            axes[2].arrow(div_col_local, div_row_local, 
                         -step[1], -step[0], 
                         head_width=2, head_length=2, fc='blue', ec='blue', linewidth=3,
                         label='FlexDTW backpointer')
    
    axes[2].plot(wp_flex_local[:, 1], wp_flex_local[:, 0], 'b-', linewidth=2, alpha=0.7, label='FlexDTW')
    axes[2].plot(wp_parflex_local[:, 1], wp_parflex_local[:, 0], 'r-', linewidth=2, alpha=0.7, label='Parflex')
    axes[2].plot(div_local[1], div_local[0], 'ro', markersize=15, markeredgecolor='black', markeredgewidth=2)
    axes[2].set_title('Backpointer Analysis', fontsize=12, fontweight='bold')
    axes[2].set_xlabel('Column')
    axes[2].set_ylabel('Row')
    axes[2].legend()
    
    plt.tight_layout()
    return fig, axes

# %% [markdown]
# ## 7. Detailed Analysis Report

# %%
def generate_divergence_report(C, D_flex, B_flex, S_flex, wp_flex, wp_parflex, 
                                intersection_point, chunks_dict, tiled_result):
    """
    Generate comprehensive text report of divergence analysis.
    
    Parameters:
    -----------
    C, D_flex, B_flex, S_flex : ndarray
        Cost, accumulated cost, backpointer, and start position matrices
    wp_flex, wp_parflex : ndarray
        Warping paths
    intersection_point : tuple
        (row, col) global coordinates
    chunks_dict : dict
        Dictionary from chunk_flexdtw
    tiled_result : dict
        Result from Parflex.align_system_parflex
    """
    inter_row, inter_col = intersection_point
    
    print("=" * 80)
    print("DIVERGENCE ANALYSIS REPORT")
    print("=" * 80)
    print(f"\nIntersection Point: ({inter_row}, {inter_col})")
    
    # Cost matrix values
    print(f"\n--- Cost Matrix Values ---")
    print(f"C[{inter_row}, {inter_col}] = {C[inter_row, inter_col]:.6f}")
    print(f"D_flex[{inter_row}, {inter_col}] = {D_flex[inter_row, inter_col]:.6f}")
    
    # Path indices
    flex_idx = np.where((wp_flex[:, 0] == inter_row) & (wp_flex[:, 1] == inter_col))[0]
    parflex_idx = np.where((wp_parflex[:, 0] == inter_row) & (wp_parflex[:, 1] == inter_col))[0]
    
    if len(flex_idx) > 0 and len(parflex_idx) > 0:
        flex_idx = flex_idx[0]
        parflex_idx = parflex_idx[0]
        
        print(f"\n--- Path Information ---")
        print(f"FlexDTW path index: {flex_idx} / {len(wp_flex)}")
        print(f"Parflex path index: {parflex_idx} / {len(wp_parflex)}")
        
        # Find divergence
        div_idx1, div_idx2, div_point = find_divergence_point(
            wp_flex, wp_parflex, flex_idx, parflex_idx
        )
        
        if div_point:
            div_row, div_col = div_point
            print(f"\n--- Divergence Point ---")
            print(f"Divergence at: ({div_row}, {div_col})")
            print(f"FlexDTW path index: {div_idx1}")
            print(f"Parflex path index: {div_idx2}")
            
            # Cost at divergence
            print(f"\nC[{div_row}, {div_col}] = {C[div_row, div_col]:.6f}")
            print(f"D_flex[{div_row}, {div_col}] = {D_flex[div_row, div_col]:.6f}")
            
            # Backpointer analysis
            bp_idx = int(B_flex[div_row, div_col])
            steps = np.array([[1, 1], [1, 2], [2, 1]])
            if 0 <= bp_idx < len(steps):
                step = steps[bp_idx]
                prev_row = div_row - step[0]
                prev_col = div_col - step[1]
                print(f"\n--- FlexDTW Path Choice ---")
                print(f"Backpointer index: {bp_idx}")
                print(f"Step taken: ({step[0]}, {step[1]})")
                print(f"Previous point: ({prev_row}, {prev_col})")
                print(f"D_flex[{prev_row}, {prev_col}] = {D_flex[prev_row, prev_col]:.6f}")
            
            # Parflex path choice
            if div_idx2 < len(wp_parflex) - 1:
                parflex_next = wp_parflex[div_idx2 + 1]
                parflex_step = (parflex_next[0] - div_row, parflex_next[1] - div_col)
                print(f"\n--- Parflex Path Choice ---")
                print(f"Next point: ({parflex_next[0]}, {parflex_next[1]})")
                print(f"Step taken: ({parflex_step[0]}, {parflex_step[1]})")
        
        # Start position analysis
        print(f"\n--- Start Position (S matrix) ---")
        s_val = S_flex[inter_row, inter_col]
        if s_val > 0:
            start_row, start_col = 0, int(s_val)
            print(f"S[{inter_row}, {inter_col}] = {s_val:.0f} → start at bottom edge: ({start_row}, {start_col})")
        elif s_val < 0:
            start_row, start_col = abs(int(s_val)), 0
            print(f"S[{inter_row}, {inter_col}] = {s_val:.0f} → start at left edge: ({start_row}, {start_col})")
        else:
            print(f"S[{inter_row}, {inter_col}] = 0 → start at origin")
    
    # Chunk analysis
    chunk_info = identify_chunk_at_point(tiled_result, inter_row, inter_col)
    if chunk_info:
        print(f"\n--- Chunk Information ---")
        print(f"Chunk: {chunk_info['chunk']}")
        print(f"Local coordinates: ({chunk_info['local_row']}, {chunk_info['local_col']})")
        print(f"Chunk bounds: rows [{chunk_info['bounds'][0]}, {chunk_info['bounds'][1]}), "
              f"cols [{chunk_info['bounds'][2]}, {chunk_info['bounds'][3]})")
        
        # Analyze chunk contribution
        chunk_analysis = analyze_chunk_contribution(
            chunks_dict, chunk_info['chunk'][0], chunk_info['chunk'][1], intersection_point
        )
        if chunk_analysis:
            print(f"\n--- Chunk-Level Values ---")
            if chunk_analysis['D_value'] is not None:
                print(f"D_chunk[{chunk_analysis['local_coords'][0]}, {chunk_analysis['local_coords'][1]}] = "
                      f"{chunk_analysis['D_value']:.6f}")
            if chunk_analysis['S_value'] is not None:
                print(f"S_chunk[{chunk_analysis['local_coords'][0]}, {chunk_analysis['local_coords'][1]}] = "
                      f"{chunk_analysis['S_value']:.0f}")
            if chunk_analysis['C_value'] is not None:
                print(f"C_chunk[{chunk_analysis['local_coords'][0]}, {chunk_analysis['local_coords'][1]}] = "
                      f"{chunk_analysis['C_value']:.6f}")
            
            # Check if on chunk boundary
            block = chunk_info['block']
            rows, cols = block['Ck_shape']
            local_r, local_c = chunk_info['local_row'], chunk_info['local_col']
            
            on_top_edge = (local_r == rows - 1)
            on_right_edge = (local_c == cols - 1)
            
            if on_top_edge or on_right_edge:
                print(f"\n--- Chunk Boundary Analysis ---")
                if on_top_edge:
                    print(f"Point is on TOP edge of chunk")
                if on_right_edge:
                    print(f"Point is on RIGHT edge of chunk")
                
                # Check previous chunk costs
                chunk_i, chunk_j = chunk_info['chunk']
                if chunk_i > 0 or chunk_j > 0:
                    print(f"\nThis path may incorporate costs from previous chunks.")
    
    print("\n" + "=" * 80)

# %% [markdown]
# ## 8. Main Execution

# %%
# Create output directory
output_dir = Path("path_divergence_analysis")
output_dir.mkdir(exist_ok=True)

# Process each intersection
if len(intersections) > 0:
    # Use first intersection for detailed analysis
    inter = intersections[0]
    intersection_point = inter['point']
    
    print(f"\nAnalyzing intersection at {intersection_point}")
    print(f"FlexDTW index: {inter['idx1']}, Parflex index: {inter['idx2']}")
    
    # Generate detailed report
    generate_divergence_report(
        C, D_flex, B_flex, P_flex, wp_flex, wp_parflex,
        intersection_point, tiled_result['chunks_dict'], tiled_result
    )
    
    # Create visualizations
    print("\nGenerating visualizations...")
    
    # 1. Zoomed view around intersection
    fig1, ax1 = plot_path_comparison_zoom(C, wp_flex, wp_parflex, intersection_point, window_size=200)
    fig1.savefig(output_dir / "cost_matrix_intersection.png", dpi=150, bbox_inches='tight')
    print(f"Saved: {output_dir / 'cost_matrix_intersection.png'}")
    
    # 2. Divergence analysis
    div_idx1, div_idx2, div_point = find_divergence_point(
        wp_flex, wp_parflex, inter['idx1'], inter['idx2']
    )
    if div_point:
        fig2, axes2 = plot_divergence_analysis(
            C, D_flex, B_flex, wp_flex, wp_parflex,
            inter['idx1'], div_idx1, radius=30
        )
        if fig2:
            fig2.savefig(output_dir / "divergence_analysis.png", dpi=150, bbox_inches='tight')
            print(f"Saved: {output_dir / 'divergence_analysis.png'}")
    
    # 3. Detailed neighborhood view
    C_local, row_range, col_range = extract_cost_neighborhood(
        C, intersection_point[0], intersection_point[1], radius=50
    )
    wp_flex_local, _ = map_path_to_local(wp_flex, *row_range, *col_range)
    wp_parflex_local, _ = map_path_to_local(wp_parflex, *row_range, *col_range)
    inter_local = (intersection_point[0] - row_range[0], intersection_point[1] - col_range[0])
    
    if div_point:
        div_local = (div_point[0] - row_range[0], div_point[1] - col_range[0])
    else:
        div_local = None
    
    fig3, ax3 = plot_cost_matrix_with_paths(
        C_local, wp_flex_local, wp_parflex_local, inter_local, div_local,
        row_range, col_range, title="Detailed Neighborhood View"
    )
    fig3.savefig(output_dir / "divergence_zoom.png", dpi=150, bbox_inches='tight')
    print(f"Saved: {output_dir / 'divergence_zoom.png'}")
    
    plt.show()
    
else:
    print("No intersections found between paths.")
# Out:
# No intersections found between paths.
